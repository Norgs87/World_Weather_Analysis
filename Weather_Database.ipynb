# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import timeit.
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# rikitea pf
# bambous virieux mu
# mount gambier au
# nagato jp
# mahadday weyne so
# sistranda no
# saleaula ws
# progreso mx
# houston ca
# hobart au
# mahibadhoo mv
# xuanhua cn
# arica cl
# taolanaro mg
# ushuaia ar
# hilo us
# pacific grove us
# ribeira grande pt
# labuhan id
# illoqqortoormiut gl
# labuhan id
# encheng cn
# port alfred za
# rikitea pf
# key largo us
# mataura pf
# caravelas br
# rimbey ca
# hovd mn
# hilo us
# tiksi ru
# victoria sc
# meulaboh id
# shache cn
# punta arenas cl
# andenes no
# cape town za
# menongue ao
# rikitea pf
# tezu in
# nishihara jp
# makat kz
# ushuaia ar
# flin flon ca
# holme no
# vestmannaeyjar is
# port alfred za
# tasbuget kz
# kawalu id
# lebu cl
# mataura pf
# georgetown sh
# alofi nu
# andrushivka ua
# nyurba ru
# rikitea pf
# busselton au
# albany au
# new norfolk au
# longyearbyen sj
# chuy uy
# vargashi ru
# bluff nz
# rikitea pf
# finschhafen pg
# olavarria ar
# albany au
# atuona pf
# kavieng pg
# torbay ca
# dorado us
# hilo us
# lata sb
# rikitea pf
# busselton au
# cape town za
# ranong th
# pundaguitan ph
# hermanus za
# fatehpur in
# roebourne au
# taolanaro mg
# matara lk
# havre-saint-pierre ca
# port alfred za
# castro cl
# kapoeta sd
# nikolskoye ru
# nalut ly
# albany au
# montrose us
# illoqqortoormiut gl
# nishihara jp
# barrow us
# butembo cd
# prince rupert ca
# altay cn
# rikitea pf
# ribeira grande pt
# linxia cn
# amderma ru
# borger us
# katherine au
# hami cn
# ushuaia ar
# busselton au
# carnarvon au
# attawapiskat ca
# port hardy ca
# jamestown sh
# mandasa in
# kenai us
# qaqortoq gl
# albany au
# pisco pe
# kutum sd
# portland au
# bahia blanca ar
# ilulissat gl
# talnakh ru
# flinders au
# puerto escondido mx
# hwange zw
# kavieng pg
# taolanaro mg
# katsuura jp
# dolinsk ru
# cabo san lucas mx
# albany au
# bluff nz
# limbang my
# hermanus za
# hofn is
# carutapera br
# busselton au
# thompson ca
# port alfred za
# aklavik ca
# kahului us
# bluff nz
# lebu cl
# port elizabeth za
# rikitea pf
# hobyo so
# rikitea pf
# khatanga ru
# airai pw
# port lincoln au
# mersing my
# new norfolk au
# cururupu br
# carnarvon au
# ranong th
# busselton au
# banyumas id
# qaanaaq gl
# xifeng cn
# znamenskoye ru
# cape town za
# hobart au
# terrace ca
# tasiilaq gl
# mar del plata ar
# ushuaia ar
# juneau us
# burica pa
# ushuaia ar
# morondava mg
# saint-philippe re
# mahebourg mu
# mahanoro mg
# cuamba mz
# mataura pf
# jishui cn
# punta arenas cl
# meulaboh id
# abbeville us
# aksu cn
# longlac ca
# hasaki jp
# vaini to
# ribeira grande pt
# guerrero negro mx
# puerto baquerizo moreno ec
# fortuna us
# amderma ru
# half moon bay us
# khatanga ru
# atuona pf
# lagoa pt
# essenbach de
# bredasdorp za
# punta arenas cl
# azimur ma
# hermanus za
# kodiak us
# cape town za
# ilulissat gl
# ushuaia ar
# saskylakh ru
# hambantota lk
# kapaa us
# yellowknife ca
# vostok ru
# arraial do cabo br
# atuona pf
# hermanus za
# reconquista ar
# shieli kz
# college us
# illoqqortoormiut gl
# palu id
# naryan-mar ru
# albany au
# hobart au
# touros br
# barrow us
# akyab mm
# albany au
# ushuaia ar
# rikitea pf
# nikolskoye ru
# masjed-e soleyman ir
# rikitea pf
# sinkat sd
# albany au
# ngaoundere cm
# yellowknife ca
# rawson ar
# yellowknife ca
# kirakira sb
# punta arenas cl
# avarua ck
# hermanus za
# brindisi it
# new norfolk au
# belushya guba ru
# shaunavon ca
# ushuaia ar
# georgetown sh
# mataura pf
# longyearbyen sj
# mahebourg mu
# thap than th
# punta arenas cl
# chokurdakh ru
# atar mr
# liverpool ca
# new norfolk au
# kita ml
# skalistyy ru
# ondorhaan mn
# yellowknife ca
# punta arenas cl
# karaul ru
# katsuura jp
# kodiak us
# ilulissat gl
# kahului us
# busselton au
# ushuaia ar
# aswan eg
# kapaa us
# karasjok no
# samusu ws
# albany au
# saskylakh ru
# hithadhoo mv
# lolua tv
# kapaa us
# yulara au
# belushya guba ru
# tiksi ru
# katsuura jp
# hermanus za
# avarua ck
# campina grande do sul br
# cabo san lucas mx
# kapaa us
# avarua ck
# ust-kulom ru
# hilo us
# ushuaia ar
# albany au
# sentyabrskiy ru
# ushuaia ar
# kalaleh ir
# bushehr ir
# vaini to
# hobart au
# berezovka ru
# oussouye sn
# shihezi cn
# bambous virieux mu
# sur om
# pompeia br
# vestmanna fo
# burnie au
# arraial do cabo br
# namibe ao
# busselton au
# bluff nz
# arraial do cabo br
# freeport us
# omsukchan ru
# san cristobal ec
# illoqqortoormiut gl
# vidim ru
# fortuna us
# bambous virieux mu
# rikitea pf
# ushuaia ar
# atuona pf
# barrow us
# hermanus za
# bredasdorp za
# tombouctou ml
# cockburn town bs
# kapaa us
# weymouth gb
# castro cl
# moerai pf
# rikitea pf
# barrow us
# yellowknife ca
# malpe in
# punta arenas cl
# ribeira grande pt
# brigantine us
# cidreira br
# jamestown sh
# madikeri in
# saint george bm
# albany au
# ponta do sol cv
# florina gr
# cumra tr
# rikitea pf
# plettenberg bay za
# okhotsk ru
# shar kz
# albany au
# balikpapan id
# nalut ly
# mataura pf
# maceio br
# vaini to
# bredasdorp za
# hobart au
# mahebourg mu
# hofn is
# saskylakh ru
# sanary-sur-mer fr
# ibra om
# barrow us
# turayf sa
# kamenskoye ru
# grand forks us
# bambous virieux mu
# palmer us
# kodiak us
# san patricio mx
# nizhneyansk ru
# busselton au
# bilma ne
# cidreira br
# albany au
# dasoguz tm
# mandurah au
# chokurdakh ru
# illoqqortoormiut gl
# bluff nz
# arraial do cabo br
# sao filipe cv
# sturgeon bay us
# mocambique mz
# vanimo pg
# estelle us
# rikitea pf
# taolanaro mg
# port alfred za
# hobart au
# faanui pf
# jamestown sh
# barentsburg sj
# cabedelo br
# puerto ayora ec
# kapaa us
# taoudenni ml
# saskylakh ru
# vao nc
# busselton au
# amderma ru
# inhambane mz
# qaanaaq gl
# jutai br
# port hardy ca
# busselton au
# ballina au
# norman wells ca
# port lincoln au
# novoagansk ru
# port alfred za
# katsuura jp
# ilulissat gl
# bluff nz
# ushuaia ar
# husavik is
# punta arenas cl
# busselton au
# nemuro jp
# mataura pf
# gemena cd
# petrozavodsk ru
# nantucket us
# illoqqortoormiut gl
# katsuura jp
# bambous virieux mu
# tiruvannamalai in
# shagonar ru
# hobart au
# marcona pe
# louisbourg ca
# zhanaozen kz
# ganzhou cn
# klaksvik fo
# isilkul ru
# nouadhibou mr
# puerto ayora ec
# georgetown sh
# chapais ca
# vaini to
# nanortalik gl
# taburi ph
# vaini to
# hobart au
# san quintin mx
# sal rei cv
# tungkang tw
# chokurdakh ru
# sur om
# hokitika nz
# atuona pf
# cap malheureux mu
# pangkalanbuun id
# porto novo cv
# new norfolk au
# ushuaia ar
# gupitan ph
# mount gambier au
# iqaluit ca
# silale lt
# fare pf
# pointe michel dm
# tura ru
# rikitea pf
# cherskiy ru
# nizhneyansk ru
# rikitea pf
# butaritari ki
# baghdad iq
# castro cl
# mataura pf
# rikitea pf
# hobart au
# cherskiy ru
# barrow us
# ushuaia ar
# mahebourg mu
# aguimes es
# mendi pg
# shahreza ir
# vaini to
# ust-nera ru
# beloha mg
# east london za
# lorengau pg
# aden ye
# arraial do cabo br
# vila franca do campo pt
# mataura pf
# butaritari ki
# butaritari ki
# ribeira grande pt
# rikitea pf
# upernavik gl
# atuona pf
# gayeri bf
# port alfred za
# rikitea pf
# cravo norte co
# sorvag fo
# bengkulu id
# hilo us
# broome au
# walajabad in
# katsuura jp
# east london za
# talnakh ru
# avarua ck
# oxelosund se
# puerto ayora ec
# ensenada mx
# ancud cl
# taburi ph
# tasiilaq gl
# belyy yar ru
# cape town za
# punta arenas cl
# hermanus za
# dikson ru
# vaitupu wf
# atuona pf
# airai pw
# ixtapa mx
# port elizabeth za
# bengkulu id
# illoqqortoormiut gl
# san patricio mx
# rikitea pf
# vagur fo
# vaini to
# kapaa us
# ushuaia ar
# hilo us
# ushuaia ar
# calama cl
# vaini to
# vardo no
# mar del plata ar
# bredasdorp za
# tuktoyaktuk ca
# east london za
# ixtapa mx
# flinders au
# longyearbyen sj
# bluff nz
# albany au
# touros br
# butaritari ki
# jamestown sh
# nuevo casas grandes mx
# busselton au
# busselton au
# sitka us
# butaritari ki
# mount gambier au
# bredasdorp za
# hermanus za
# kavieng pg
# mataura pf
# airai pw
# beringovskiy ru
# cape town za
# gidole et
# nishihara jp
# vaini to
# ushuaia ar
# port shepstone za
# albany au
# sisian am
# arraial do cabo br
# ushuaia ar
# busselton au
# cabedelo br
# hasaki jp
# tshela cd
# mayumba ga
# longuenesse fr
# pevek ru
# avarua ck
# saldanha za
# mys shmidta ru
# margate za
# thompson ca
# cape town za
# decatur us
# avarua ck
# mataura pf
# chapais ca
# chandler ca
# ribeira grande pt
# plettenberg bay za
# la ronge ca
# upernavik gl
# luderitz na
# victoria sc
# souillac mu
# tarko-sale ru
# torbay ca
# jamestown sh
# avarua ck
# lalomanu ws
# ixtapa mx
# rikitea pf
# hermanus za
# bredasdorp za
# saint-philippe re
# rize tr
# mar del plata ar
# taolanaro mg
# lebu cl
# ayorou ne
# anadyr ru
# port elizabeth za
# mataura pf
# busselton au
# puerto ayora ec
# cervo es
# mataura pf
# taseyevo ru
# aykhal ru
# rikitea pf
# udachnyy ru
# hilo us
# port alfred za
# pevek ru
# sitka us
# rikitea pf
# rikitea pf
# ushuaia ar
# yellowknife ca
# solovetskiy ru
# gorin ru
# bengkulu id
# yellowknife ca
# mataura pf
# rikitea pf
# nanortalik gl
# inuvik ca
# chapais ca
# barrow us
# castro cl
# lagoa pt
# sioux lookout ca
# klaksvik fo
# tome cl
# hobart au
# busselton au
# inhambane mz
# tsihombe mg
# mataura pf
# tromso no
# beyneu kz
# rikitea pf
# port alfred za
# kampot kh
# rocha uy
# rikitea pf
# hermanus za
# itarema br
# abu dhabi ae
# port alfred za
# bandarbeyla so
# tiksi ru
# bambous virieux mu
# hualmay pe
# paracuru br
# taolanaro mg
# ust-ilimsk ru
# escanaba us
# castro cl
# chenghai cn
# bambous virieux mu
# yar-sale ru
# madarounfa ne
# qaanaaq gl
# barentsburg sj
# puerto ayora ec
# avarua ck
# port alfred za
# fortuna us
# tiksi ru
# khatanga ru
# mazyr by
# nikolskoye ru
# illoqqortoormiut gl
# dikson ru
# huarmey pe
# huarmey pe
# mys shmidta ru
# hobart au
# finnsnes no
# cherskiy ru
# riohacha co
# bengkulu id
# khatanga ru
# bluff nz
# albany au
# saint-philippe re
# albany au
# bluff nz
# arraial do cabo br
# tuktoyaktuk ca
# broken hill au
# rio grande br
# flinders au
# geraldton au
# kapaa us
# rungata ki
# punta arenas cl
# gari ru
# ponta do sol cv
# new norfolk au
# iqaluit ca
# ushuaia ar
# kapaa us
# la ronge ca
# tuxpan mx
# yellowknife ca
# kjollefjord no
# barbar sd
# belushya guba ru
# nabire id
# ushuaia ar
# marsh harbour bs
# hobart au
# north bend us
# qaanaaq gl
# vestmannaeyjar is
# mataura pf
# punta arenas cl
# harrogate gb
# andenes no
# cartagena co
# necochea ar
# albany au
# punta arenas cl
# rawson ar
# tonstad no
# nalagarh in
# mataura pf
# dikson ru
# nizhneyansk ru
# puerto rico co
# mar del plata ar
# bluff nz
# illoqqortoormiut gl
# mataura pf
# east london za
# east london za
# airai pw
# micheweni tz
# kaitangata nz
# arraial do cabo br
# tasiilaq gl
# nanortalik gl
# jinchang cn
# inirida co
# bluff nz
# jarjis tn
# singaraja id
# colquiri bo
# butaritari ki
# yellowknife ca
# torbay ca
# srednekolymsk ru
# hasaki jp
# rikitea pf
# fortuna us
# hede cn
# durg in
# tabiauea ki
# illoqqortoormiut gl
# waipawa nz
# westport ie
# katsuura jp
# tsihombe mg
# illoqqortoormiut gl
# taolanaro mg
# coquimbo cl
# rikitea pf
# college us
# mys shmidta ru
# cape town za
# omboue ga
# yellowknife ca
# mahon es
# puerto madero mx
# saint-pierre pm
# tazovskiy ru
# hobart au
# barentsburg sj
# albany au
# taolanaro mg
# cravinhos br
# nome us
# itoman jp
# sitka us
# vardo no
# karaul ru
# maputo mz
# amderma ru
# albany au
# harper lr
# elko us
# amderma ru
# bischofshofen at
# avarua ck
# avera pf
# port elizabeth za
# nikolskoye ru
# grand gaube mu
# rikitea pf
# rikitea pf
# half moon bay us
# cape town za
# tasiilaq gl
# beringovskiy ru
# havre us
# hurghada eg
# hermanus za
# tallahassee us
# antofagasta cl
# saskylakh ru
# khash ir
# atuona pf
# bow island ca
# snezhnogorsk ru
# ngunguru nz
# port elizabeth za
# coquimbo cl
# upernavik gl
# iqaluit ca
# vaini to
# caceres es
# kapaa us
# russell nz
# mindelo cv
# shahr-e babak ir
# glendive us
# rocha uy
# east london za
# saint george bm
# rikitea pf
# mackay au
# leningradskiy ru
# qaanaaq gl
# albany au
# hobart au
# illoqqortoormiut gl
# hilo us
# punta arenas cl
# upernavik gl
# ovsyanka ru
# rikitea pf
# gympie au
# filingue ne
# cape town za
# quatre cocos mu
# astoria us
# mataura pf
# marcona pe
# bluff nz
# upernavik gl
# basco ph
# albany au
# ambon id
# mahonda tz
# sentyabrskiy ru
# hermanus za
# jamestown sh
# sao jose da coroa grande br
# torbay ca
# carnarvon au
# rikitea pf
# georgetown sh
# hilo us
# nanortalik gl
# naze jp
# qaanaaq gl
# longyearbyen sj
# klaksvik fo
# conde br
# palabuhanratu id
# rikitea pf
# port hedland au
# chokurdakh ru
# sorland no
# ugoofaaru mv
# ushuaia ar
# punta arenas cl
# mar del plata ar
# hokitika nz
# zhuhai cn
# yellowknife ca
# port alfred za
# northam au
# lasa cn
# bredasdorp za
# butaritari ki
# kapaa us
# rikitea pf
# det udom th
# vestmanna fo
# hambantota lk
# karratha au
# rikitea pf
# yellowknife ca
# carnarvon au
# ushuaia ar
# ponta delgada pt
# port elizabeth za
# cape town za
# arlit ne
# port elizabeth za
# rikitea pf
# punta arenas cl
# rikitea pf
# waipawa nz
# khatanga ru
# kodiak us
# vallenar cl
# jumla np
# ribeira grande pt
# tiksi ru
# hithadhoo mv
# salekhard ru
# faya td
# bluff nz
# ketchikan us
# taolanaro mg
# tiksi ru
# oktyabrskiy ru
# romilly-sur-seine fr
# tocopilla cl
# tasiilaq gl
# provideniya ru
# kendari id
# arraial do cabo br
# yellowknife ca
# bambous virieux mu
# mataura pf
# barrow us
# touros br
# illoqqortoormiut gl
# tuktoyaktuk ca
# cherskiy ru
# severo-kurilsk ru
# grindavik is
# punta arenas cl
# vaini to
# honiara sb
# honiara sb
# comodoro rivadavia ar
# busselton au
# bredasdorp za
# sao filipe cv
# saint-philippe re
# hobart au
# lebu cl
# bredasdorp za
# tuktoyaktuk ca
# dunedin nz
# albany au
# sao filipe cv
# lazaro cardenas mx
# mar del plata ar
# ushuaia ar
# bambous virieux mu
# myitkyina mm
# rikitea pf
# kavaratti in
# canatlan mx
# la ronge ca
# skaudvile lt
# port macquarie au
# mataura pf
# korla cn
# buqayq sa
# cape town za
# illoqqortoormiut gl
# hasaki jp
# hilo us
# labuhan id
# bonfim br
# hilo us
# vaini to
# katherine au
# ushuaia ar
# saldanha za
# petropavlovsk-kamchatskiy ru
# guerrero negro mx
# hermanus za
# ponta do sol cv
# gulshat kz
# rikitea pf
# kuryk kz
# lebu cl
# jamestown sh
# nago jp
# hasaki jp
# clyde river ca
# nizwa om
# barrow us
# luau ao
# ngama td
# rikitea pf
# hilo us
# rikitea pf
# barentsburg sj
# hirna et
# tasiilaq gl
# hithadhoo mv
# portland au
# rikitea pf
# busselton au
# tuktoyaktuk ca
# changde cn
# qaanaaq gl
# cap malheureux mu
# dikson ru
# palabuhanratu id
# hilo us
# tasiilaq gl
# acapulco mx
# mahebourg mu
# dikson ru
# alofi nu
# qaanaaq gl
# tomatlan mx
# barentsburg sj
# upernavik gl
# ushuaia ar
# atuona pf
# san juan us
# humboldt ca
# grindavik is
# punta arenas cl
# salalah om
# albany au
# san patricio mx
# thompson ca
# punta arenas cl
# plettenberg bay za
# presidencia roque saenz pena ar
# atambua id
# qaanaaq gl
# ancud cl
# thompson ca
# busselton au
# mataura pf
# mataura pf
# ossora ru
# santa cruz del sur cu
# zhengjiatun cn
# rikitea pf
# bokoro td
# albany au
# bredasdorp za
# jamestown sh
# port alfred za
# saint-philippe re
# qaqortoq gl
# komsomolskiy ru
# bethel us
# ballina au
# albany au
# albany au
# darhan mn
# chuy uy
# hermanus za
# leh in
# tiksi ru
# ponta do sol cv
# nikolskoye ru
# albany au
# calvinia za
# bluff nz
# lompoc us
# ribeira grande pt
# qaanaaq gl
# omboue ga
# harper lr
# clinton us
# jijiga et
# chokurdakh ru
# port alfred za
# ouegoa nc
# mar del plata ar
# cidreira br
# punta arenas cl
# myaundzha ru
# samarai pg
# hermanus za
# el dorado co
# praia da vitoria pt
# busselton au
# kodiak us
# hambantota lk
# taolanaro mg
# guerrero negro mx
# vila velha br
# santiago br
# busselton au
# sidney us
# kodiak us
# tuktoyaktuk ca
# gat ly
# castro cl
# matozinhos br
# busselton au
# jamestown sh
# lorengau pg
# yeniseysk ru
# arraial do cabo br
# pevek ru
# mahebourg mu
# punta arenas cl
# kaeo nz
# taolanaro mg
# east london za
# esperance au
# kavaratti in
# coquimbo cl
# jamestown sh
# los llanos de aridane es
# chokurdakh ru
# victoria sc
# port macquarie au
# hay river ca
# korgen no
# opuwo na
# lolua tv
# vaitupu wf
# chokurdakh ru
# vaini to
# petropavlovsk-kamchatskiy ru
# bluff nz
# busselton au
# nikolskoye ru
# lorengau pg
# kodiak us
# sao felix do xingu br
# albany au
# bluff nz
# dangriga bz
# mataura pf
# viligili mv
# rikitea pf
# mahebourg mu
# vaini to
# xai-xai mz
# avarua ck
# verkhoyansk ru
# rabo de peixe pt
# chokurdakh ru
# rikitea pf
# taolanaro mg
# hermanus za
# iralaya hn
# mar del plata ar
# khatanga ru
# georgetown sh
# vaini to
# upernavik gl
# hithadhoo mv
# hilo us
# namibe ao
# atikokan ca
# ganzhou cn
# attawapiskat ca
# wodonga au
# senanga zm
# kozloduj bg
# kijang id
# bagli in
# bilma ne
# zaria ng
# belushya guba ru
# glendive us
# albany au
# port jervis us
# ushuaia ar
# hithadhoo mv
# ushuaia ar
# raga sd
# thompson ca
# morehead pg
# talnakh ru
# hermanus za
# hithadhoo mv
# huarmey pe
# lima pe
# albany au
# vaini to
# rikitea pf
# ilulissat gl
# torbay ca
# mataura pf
# clyde river ca
# unity ca
# san policarpo ph
# chicama pe
# seguin us
# sidi ali dz
# mys shmidta ru
# new norfolk au
# chokurdakh ru
# mar del plata ar
# la ronge ca
# mataura pf
# busselton au
# emerald au
# san ignacio bo
# hobart au
# redlands us
# avarua ck
# hilo us
# pangkalanbuun id
# hobart au
# constitucion mx
# flin flon ca
# maine-soroa ne
# yerbogachen ru
# ksenyevka ru
# busselton au
# bowling green us
# sao joao da barra br
# shingu jp
# katangli ru
# pirganj bd
# busselton au
# hithadhoo mv
# airai pw
# coahuayana mx
# codrington ag
# hermanus za
# moyeuvre-grande fr
# grand river south east mu
# bengkulu id
# katsuura jp
# provideniya ru
# hithadhoo mv
# novikovo ru
# mukhen ru
# pisco pe
# ormara pk
# zhangjiakou cn
# haibowan cn
# albany au
# nyurba ru
# belushya guba ru
# korla cn
# buala sb
# saluzzo it
# korla cn
# la ciotat fr
# hermanus za
# mataura pf
# lavrentiya ru
# klaksvik fo
# barrow us
# zhuhai cn
# bredasdorp za
# cape town za
# ponta do sol pt
# katsuura jp
# kaitangata nz
# albany au
# mataura pf
# vaini to
# rikitea pf
# hobart au
# yuty py
# wahiawa us
# temaraia ki
# ambodifototra mg
# ginda er
# kahului us
# flinders au
# ushuaia ar
# arraial do cabo br
# aykhal ru
# lebu cl
# barentsburg sj
# ngunguru nz
# dafeng cn
# atar mr
# ushuaia ar
# paamiut gl
# nikolskoye ru
# cape town za
# fare pf
# haines junction ca
# nanortalik gl
# balaipungut id
# port alfred za
# butaritari ki
# bathsheba bb
# pamanukan id
# sorong id
# elko us
# mahebourg mu
# hirara jp
# tuktoyaktuk ca
# esperance au
# ushuaia ar
# kapaa us
# ratnapura lk
# ola ru
# mergui mm
# launceston au
# bredasdorp za
# la palma pa
# atuona pf
# hobart au
# hobart au
# hobart au
# cabo san lucas mx
# presidencia roque saenz pena ar
# punta arenas cl
# castro cl
# kamenskoye ru
# marcona pe
# cape town za
# carnarvon au
# beirut lb
# half moon bay us
# punta arenas cl
# lorengau pg
# ledyard us
# qaanaaq gl
# hermanus za
# mingshui cn
# busselton au
# arraial do cabo br
# gushikawa jp
# jalu ly
# upernavik gl
# pisco pe
# narsaq gl
# fairbanks us
# ushuaia ar
# port alfred za
# ribeira grande pt
# ushuaia ar
# cayenne gf
# bluff nz
# vaitupu wf
# kurilsk ru
# bengkulu id
# bredasdorp za
# vostok ru
# kananga cd
# saint-philippe re
# manokwari id
# rikitea pf
# santa cruz cr
# sao gabriel da cachoeira br
# tuatapere nz
# arona es
# inhambane mz
# san cristobal ec
# gaoual gn
# rikitea pf
# sentyabrskiy ru
# airai pw
# tabou ci
# mount gambier au
# lom sak th
# vila velha br
# iqaluit ca
# lavrentiya ru
# ozieri it
# butaritari ki
# alyangula au
# busselton au
# truro ca
# borovoy ru
# severo-kurilsk ru
# rikitea pf
# touros br
# mataura pf
# yar-sale ru
# richards bay za
# carnarvon au
# rikitea pf
# caravelas br
# sola vu
# ust-karsk ru
# klaksvik fo
# bilibino ru
# cabo san lucas mx
# albany au
# tuktoyaktuk ca
# tidore id
# moyale ke
# srednekolymsk ru
# busselton au
# isangel vu
# port alfred za
# los llanos de aridane es
# nhulunbuy au
# kavieng pg
# hilo us
# butaritari ki
# mozarlandia br
# kodiak us
# lebu cl
# mataura pf
# shingu jp
# isangel vu
# sorvag fo
# arraial do cabo br
# punta arenas cl
# havre-saint-pierre ca
# taolanaro mg
# goderich sl
# deputatskiy ru
# ambodifototra mg
# lavrentiya ru
# hervey bay au
# atuona pf
# vaini to
# bathsheba bb
# yellowknife ca
# yar-sale ru
# bluff nz
# ushuaia ar
# juneau us
# illoqqortoormiut gl
# avarua ck
# arraial do cabo br
# kieta pg
# numaligarh in
# punta arenas cl
# port alfred za
# planaltina br
# minab ir
# marsa matruh eg
# rikitea pf
# rikitea pf
# ushuaia ar
# bredasdorp za
# torbay ca
# sao gabriel da cachoeira br
# ngukurr au
# tuatapere nz
# mataura pf
# carutapera br
# luanda ao
# kieta pg
# mys shmidta ru
# busselton au
# lebu cl
# punta arenas cl
# carnarvon au
# vaini to
# geraldton au
# khatanga ru
# punta arenas cl
# ushuaia ar
# rikitea pf
# cape town za
# ibarra ph
# brownwood us
# mataura pf
# keflavik is
# atuona pf
# vaini to
# hermanus za
# bengkulu id
# luderitz na
# lebu cl
# busselton au
# nha trang vn
# new norfolk au
# chute-aux-outardes ca
# willmar us
# boffa gn
# naze jp
# ust-nera ru
# cherskiy ru
# salalah om
# vaini to
# arosa ch
# port-de-bouc fr
# taolanaro mg
# castro cl
# hermanus za
# chuy uy
# cape town za
# toucheng tw
# ushuaia ar
# mount isa au
# ossora ru
# avarua ck
# qaanaaq gl
# attawapiskat ca
# new norfolk au
# vaini to
# cherskiy ru
# kazachinskoye ru
# hilo us
# san patricio mx
# mount gambier au
# svetlaya ru
# georgetown sh
# mmathubudukwane bw
# grand centre ca
# khatanga ru
# norman wells ca
# kapaa us
# vaitupu wf
# nome us
# albany au
# rikitea pf
# kapaa us
# avarua ck
# carnarvon za
# ushuaia ar
# clyde river ca
# punta arenas cl
# butaritari ki
# attawapiskat ca
# bethel us
# meulaboh id
# hithadhoo mv
# carnarvon au
# yar-sale ru
# kahului us
# qostanay kz
# shitkino ru
# east london za
# bilibino ru
# cam ranh vn
# mugan az
# the valley ai
# cherskiy ru
# lakatoro vu
# punta arenas cl
# albany au
# grand gaube mu
# dikson ru
# cape town za
# iskateley ru
# ponta do sol cv
# barrow us
# mar del plata ar
# saint-philippe re
# mahebourg mu
# vidalia us
# khatanga ru
# grand river south east mu
# vila franca do campo pt
# nara ml
# rikitea pf
# gunjur gm
# port alfred za
# vila franca do campo pt
# punta arenas cl
# punta arenas cl
# kalabo zm
# busselton au
# hilo us
# ijaki ki
# reconquista ar
# likasi cd
# yenagoa ng
# port alfred za
# rikitea pf
# mazsalaca lv
# kahului us
# hobart au
# teeli ru
# rikitea pf
# provideniya ru
# punta arenas cl
# thompson ca
# albany au
# luderitz na
# port alfred za
# cape town za
# bengkulu id
# labytnangi ru
# dhidhdhoo mv
# naze jp
# basoko cd
# mahebourg mu
# gushi cn
# santo antonio do ica br
# vaitupu wf
# castro cl
# presidencia roque saenz pena ar
# faanui pf
# daura ng
# marcona pe
# thilogne sn
# cape town za
# naftah tn
# chokurdakh ru
# puerto ayora ec
# evensk ru
# babanusah sd
# east london za
# punta arenas cl
# nanortalik gl
# mar del plata ar
# hun ly
# zeya ru
# avarua ck
# alofi nu
# meulaboh id
# upington za
# georgetown sh
# ushuaia ar
# butaritari ki
# kimbe pg
# saint-philippe re
# buchanan lr
# vaini to
# laurel us
# lompoc us
# ushuaia ar
# barrow us
# chlorakas cy
# butaritari ki
# rungata ki
# praia cv
# bairiki ki
# saleaula ws
# nikolskoye ru
# bathsheba bb
# sao jose da coroa grande br
# qaanaaq gl
# bredasdorp za
# te anau nz
# ribeira grande pt
# ancud cl
# anshun cn
# hithadhoo mv
# hermanus za
# ushuaia ar
# santa cruz de la palma es
# barrow us
# berlevag no
# bambanglipuro id
# kapaa us
# buon me thuot vn
# namibe ao
# ushuaia ar
# acapulco mx
# busselton au
# punta arenas cl
# arlit ne
# kushiro jp
# amboasary mg
# debre birhan et
# rikitea pf
# albany au
# arraial do cabo br
# qaanaaq gl
# ushuaia ar
# new norfolk au
# ancud cl
# boa vista br
# new norfolk au
# atuona pf
# san patricio mx
# taolanaro mg
# salalah om
# rikitea pf
# ancud cl
# plettenberg bay za
# leningradskiy ru
# kununurra au
# hobart au
# khash ir
# barrow us
# alice springs au
# amderma ru
# hermanus za
# ushuaia ar
# sitka us
# taburao ki
# tabiauea ki
# upernavik gl
# verkhniy rohachyk ua
# khatanga ru
# chokurdakh ru
# antalaha mg
# barrow us
# illoqqortoormiut gl
# attawapiskat ca
# gat ly
# guerrero negro mx
# ushuaia ar
# cidreira br
# vaini to
# hithadhoo mv
# saint-augustin ca
# robertsport lr
# rikitea pf
# campechuela cu
# bredasdorp za
# malanje ao
# hermanus za
# bambous virieux mu
# bluff nz
# saleaula ws
# chokurdakh ru
# wenling cn
# kulhudhuffushi mv
# henties bay na
# ushuaia ar
# punta arenas cl
# kaitangata nz
# tasiilaq gl
# cayenne gf
# mahebourg mu
# severo-kurilsk ru
# mutsamudu km
# uribia co
# suamico us
# dong xoai vn
# mataura pf
# barentsburg sj
# lagoa pt
# bluff nz
# hami cn
# oussouye sn
# georgetown sh
# cape town za
# berlevag no
# clyde river ca
# erenhot cn
# massakory td
# beringovskiy ru
# banmo mm
# hermanus za
# komsomolskiy ru
# paracuru br
# saint-pierre re
# avarua ck
# macomb us
# talnakh ru
# yellowknife ca
# rochegda ru
# leningradskiy ru
# riyadh sa
# tlaxiaco mx
# lichuan cn
# rikitea pf
# tamworth gb
# saint-leu re
# sobolevo ru
# belushya guba ru
# mashhad ir
# deputatskiy ru
# hilo us
# ushuaia ar
# rikitea pf
# vaini to
# atuona pf
# punta arenas cl
# bluff nz
# albany au
# jamestown sh
# puerto ayora ec
# yellowknife ca
# ulaanbaatar mn
# souillac mu
# pimentel pe
# karratha au
# saint-pierre pm
# tumannyy ru
# vaini to
# rikitea pf
# marv dasht ir
# port macquarie au
# kapaa us
# brae gb
# bambous virieux mu
# georgetown sh
# chimbarongo cl
# naugarzan tj
# busselton au
# teahupoo pf
# gualaquiza ec
# kaitangata nz
# beringovskiy ru
# ushuaia ar
# tual id
# yar-sale ru
# lorengau pg
# iskateley ru
# cabo san lucas mx
# rikitea pf
# yanji cn
# hurghada eg
# salinopolis br
# taburi ph
# new norfolk au
# hermanus za
# mahebourg mu
# cherskiy ru
# bredasdorp za
# dikson ru
# tuktoyaktuk ca
# shively us
# vardo no
# pundaguitan ph
# illoqqortoormiut gl
# tuktoyaktuk ca
# lata sb
# bambous virieux mu
# saldanha za
# port alfred za
# umzimvubu za
# butaritari ki
# dongsheng cn
# hermanus za
# arraial do cabo br
# punta arenas cl
# nikolskoye ru
# kapaa us
# butaritari ki
# taksimo ru
# albany au
# manadhoo mv
# mar del plata ar
# talnakh ru
# bredasdorp za
# mahebourg mu
# mataura pf
# nizhneyansk ru
# ribeira grande pt
# srisailam in
# kimbe pg
# port elizabeth za
# kirakira sb
# rikitea pf
# rikitea pf
# dese et
# illoqqortoormiut gl
# saint-philippe re
# point fortin tt
# cabanas cu
# vaini to
# aquiraz br
# aflu dz
# punta arenas cl
# kavieng pg
# albany au
# matara lk
# busselton au
# leningradskiy ru
# georgetown sh
# riyadh sa
# atuona pf
# alice springs au
# victoria sc
# yellowknife ca
# arraial do cabo br
# dikson ru
# ushuaia ar
# bambous virieux mu
# cochrane ca
# san policarpo ph
# rikitea pf
# lebu cl
# vaini to
# upernavik gl
# muravlenko ru
# rikitea pf
# aklavik ca
# hilo us
# busselton au
# cape town za
# pokosnoye ru
# nikolskoye ru
# avarua ck
# tuktoyaktuk ca
# busselton au
# longlac ca
# mahebourg mu
# beringovskiy ru
# yellowknife ca
# grand gaube mu
# cape town za
# ushuaia ar
# kaohsiung tw
# rikitea pf
# yellowknife ca
# punta arenas cl
# gorkovskiy ru
# husavik is
# umzimvubu za
# belgrade us
# zachagansk kz
# putina pe
# yellowknife ca
# nikolskoye ru
# arraial do cabo br
# khatanga ru
# kapaa us
# lasa cn
# san patricio mx
# leh in
# yabrud sy
# hobart au
# sitka us
# port hedland au
# lebu cl
# qaanaaq gl
# cayenne gf
# rikitea pf
# urazovo ru
# tiksi ru
# hermanus za
# barrow us
# talnakh ru
# cape town za
# hobart au
# beringovskiy ru
# mar del plata ar
# waipawa nz
# busselton au
# carnarvon au
# vaini to
# geraldton ca
# albany au
# cape town za
# kapuskasing ca
# tawkar sd
# victoria sc
# coria es
# jamestown sh
# sioux lookout ca
# peleduy ru
# bubaque gw
# port elizabeth za
# tasiilaq gl
# tasiilaq gl
# mataura pf
# wladyslawowo pl
# butaritari ki
# grindavik is
# punta arenas cl
# carnarvon au
# korcula hr
# belushya guba ru
# cape town za
# ushuaia ar
# khatanga ru
# bluff nz
# hihifo to
# albany au
# esperance au
# pangnirtung ca
# mongu zm
# arraial do cabo br
# tres arroyos ar
# albany au
# dikson ru
# jamestown sh
# sabzevar ir
# alta floresta br
# ponoka ca
# busselton au
# gat ly
# hamilton bm
# forbes au
# arman ru
# kapaa us
# gombe ng
# soto la marina mx
# khatanga ru
# new norfolk au
# lasa cn
# sigli id
# abu samrah qa
# victoria sc
# chokurdakh ru
# sao filipe cv
# puerto ayora ec
# cidreira br
# ushuaia ar
# gamboula cf
# uarini br
# ossora ru
# atuona pf
# bluff nz
# tommot ru
# boyolangu id
# khanpur pk
# port-gentil ga
# cape town za
# la ronge ca
# lompoc us
# moron mn
# paulo ramos br
# sosva ru
# ushuaia ar
# jamestown sh
# butaritari ki
# barentsburg sj
# esperance au
# atuona pf

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=55fbd21474beaf864ebecb1d5d7da73e&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":36.05,"feels_like":28.58,"temp_min":31.91,"temp_max":39.25,"pressure":1020,"humidity":52},"visibility":10000,"wind":{"speed":10.36,"deg":310},"clouds":{"all":100},"dt":1644733260,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1644752619,"sunset":1644790408},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 36.05,
#   'feels_like': 28.58,
#   'temp_min': 31.91,
#   'temp_max': 39.25,
#   'pressure': 1020,
#   'humidity': 52},
#  'visibility': 10000,
#  'wind': {'speed': 10.36, 'deg': 310},
#  'clouds': {'all': 100},
#  'dt': 1644733260,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1644752619,
#   'sunset': 1644790408},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | mount gambier
# Processing Record 4 of Set 1 | nagato
# Processing Record 5 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 6 of Set 1 | sistranda
# Processing Record 7 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 1 | progreso
# Processing Record 9 of Set 1 | houston
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | mahibadhoo
# Processing Record 12 of Set 1 | xuanhua
# Processing Record 13 of Set 1 | arica
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | pacific grove
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | labuhan
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | encheng
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | key largo
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | caravelas
# Processing Record 26 of Set 1 | rimbey
# Processing Record 27 of Set 1 | hovd
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | meulaboh
# Processing Record 31 of Set 1 | shache
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | andenes
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | menongue
# Processing Record 36 of Set 1 | tezu
# Processing Record 37 of Set 1 | nishihara
# Processing Record 38 of Set 1 | makat
# Processing Record 39 of Set 1 | flin flon
# Processing Record 40 of Set 1 | holme
# Processing Record 41 of Set 1 | vestmannaeyjar
# Processing Record 42 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 1 | kawalu
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | alofi
# Processing Record 47 of Set 1 | andrushivka
# Processing Record 48 of Set 1 | nyurba
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | vargashi
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | finschhafen
# Processing Record 7 of Set 2 | olavarria
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | dorado
# Processing Record 12 of Set 2 | lata
# Processing Record 13 of Set 2 | ranong
# Processing Record 14 of Set 2 | pundaguitan
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | fatehpur
# Processing Record 17 of Set 2 | roebourne
# Processing Record 18 of Set 2 | matara
# Processing Record 19 of Set 2 | havre-saint-pierre
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | kapoeta
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | nalut
# Processing Record 24 of Set 2 | montrose
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | butembo
# Processing Record 27 of Set 2 | prince rupert
# Processing Record 28 of Set 2 | altay
# Processing Record 29 of Set 2 | linxia
# Processing Record 30 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 2 | borger
# Processing Record 32 of Set 2 | katherine
# Processing Record 33 of Set 2 | hami
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | port hardy
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | mandasa
# Processing Record 39 of Set 2 | kenai
# Processing Record 40 of Set 2 | qaqortoq
# Processing Record 41 of Set 2 | pisco
# Processing Record 42 of Set 2 | kutum
# Processing Record 43 of Set 2 | portland
# Processing Record 44 of Set 2 | bahia blanca
# Processing Record 45 of Set 2 | ilulissat
# Processing Record 46 of Set 2 | talnakh
# Processing Record 47 of Set 2 | flinders
# Processing Record 48 of Set 2 | puerto escondido
# Processing Record 49 of Set 2 | hwange
# Processing Record 50 of Set 2 | katsuura
# Processing Record 1 of Set 3 | dolinsk
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | limbang
# Processing Record 4 of Set 3 | hofn
# Processing Record 5 of Set 3 | carutapera
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | aklavik
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | hobyo
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | airai
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | mersing
# Processing Record 15 of Set 3 | cururupu
# Processing Record 16 of Set 3 | banyumas
# Processing Record 17 of Set 3 | qaanaaq
# Processing Record 18 of Set 3 | xifeng
# Processing Record 19 of Set 3 | znamenskoye
# Processing Record 20 of Set 3 | terrace
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | juneau
# Processing Record 24 of Set 3 | burica
# City not found. Skipping...
# Processing Record 25 of Set 3 | morondava
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | mahanoro
# Processing Record 29 of Set 3 | cuamba
# Processing Record 30 of Set 3 | jishui
# Processing Record 31 of Set 3 | abbeville
# Processing Record 32 of Set 3 | aksu
# Processing Record 33 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 34 of Set 3 | hasaki
# Processing Record 35 of Set 3 | vaini
# Processing Record 36 of Set 3 | guerrero negro
# Processing Record 37 of Set 3 | puerto baquerizo moreno
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | half moon bay
# Processing Record 40 of Set 3 | lagoa
# Processing Record 41 of Set 3 | essenbach
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | hambantota
# Processing Record 47 of Set 3 | kapaa
# Processing Record 48 of Set 3 | yellowknife
# Processing Record 49 of Set 3 | vostok
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | reconquista
# Processing Record 2 of Set 4 | shieli
# Processing Record 3 of Set 4 | college
# Processing Record 4 of Set 4 | palu
# Processing Record 5 of Set 4 | naryan-mar
# Processing Record 6 of Set 4 | touros
# Processing Record 7 of Set 4 | akyab
# Processing Record 8 of Set 4 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 9 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 4 | ngaoundere
# Processing Record 11 of Set 4 | rawson
# Processing Record 12 of Set 4 | kirakira
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | brindisi
# Processing Record 15 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 4 | shaunavon
# Processing Record 17 of Set 4 | thap than
# Processing Record 18 of Set 4 | chokurdakh
# Processing Record 19 of Set 4 | atar
# Processing Record 20 of Set 4 | liverpool
# Processing Record 21 of Set 4 | kita
# Processing Record 22 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 4 | aswan
# Processing Record 26 of Set 4 | karasjok
# Processing Record 27 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 4 | hithadhoo
# Processing Record 29 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 4 | yulara
# Processing Record 31 of Set 4 | campina grande do sul
# Processing Record 32 of Set 4 | ust-kulom
# Processing Record 33 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | kalaleh
# Processing Record 35 of Set 4 | bushehr
# Processing Record 36 of Set 4 | berezovka
# Processing Record 37 of Set 4 | oussouye
# Processing Record 38 of Set 4 | shihezi
# Processing Record 39 of Set 4 | sur
# Processing Record 40 of Set 4 | pompeia
# Processing Record 41 of Set 4 | vestmanna
# Processing Record 42 of Set 4 | burnie
# Processing Record 43 of Set 4 | namibe
# Processing Record 44 of Set 4 | freeport
# Processing Record 45 of Set 4 | omsukchan
# Processing Record 46 of Set 4 | san cristobal
# Processing Record 47 of Set 4 | vidim
# Processing Record 48 of Set 4 | tombouctou
# Processing Record 49 of Set 4 | cockburn town
# Processing Record 50 of Set 4 | weymouth
# Processing Record 1 of Set 5 | moerai
# Processing Record 2 of Set 5 | malpe
# Processing Record 3 of Set 5 | brigantine
# Processing Record 4 of Set 5 | cidreira
# Processing Record 5 of Set 5 | madikeri
# Processing Record 6 of Set 5 | saint george
# Processing Record 7 of Set 5 | ponta do sol
# Processing Record 8 of Set 5 | florina
# Processing Record 9 of Set 5 | cumra
# Processing Record 10 of Set 5 | plettenberg bay
# Processing Record 11 of Set 5 | okhotsk
# Processing Record 12 of Set 5 | shar
# Processing Record 13 of Set 5 | balikpapan
# Processing Record 14 of Set 5 | maceio
# Processing Record 15 of Set 5 | sanary-sur-mer
# Processing Record 16 of Set 5 | ibra
# Processing Record 17 of Set 5 | turayf
# Processing Record 18 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 5 | grand forks
# Processing Record 20 of Set 5 | palmer
# Processing Record 21 of Set 5 | san patricio
# Processing Record 22 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 5 | bilma
# Processing Record 24 of Set 5 | dasoguz
# Processing Record 25 of Set 5 | mandurah
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | sturgeon bay
# Processing Record 28 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 5 | vanimo
# Processing Record 30 of Set 5 | estelle
# Processing Record 31 of Set 5 | faanui
# Processing Record 32 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 5 | cabedelo
# Processing Record 34 of Set 5 | puerto ayora
# Processing Record 35 of Set 5 | taoudenni
# Processing Record 36 of Set 5 | vao
# Processing Record 37 of Set 5 | inhambane
# Processing Record 38 of Set 5 | jutai
# Processing Record 39 of Set 5 | ballina
# Processing Record 40 of Set 5 | norman wells
# Processing Record 41 of Set 5 | novoagansk
# Processing Record 42 of Set 5 | husavik
# Processing Record 43 of Set 5 | nemuro
# Processing Record 44 of Set 5 | gemena
# Processing Record 45 of Set 5 | petrozavodsk
# Processing Record 46 of Set 5 | nantucket
# Processing Record 47 of Set 5 | tiruvannamalai
# Processing Record 48 of Set 5 | shagonar
# Processing Record 49 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 6 | zhanaozen
# Processing Record 2 of Set 6 | ganzhou
# Processing Record 3 of Set 6 | klaksvik
# Processing Record 4 of Set 6 | isilkul
# Processing Record 5 of Set 6 | nouadhibou
# Processing Record 6 of Set 6 | chapais
# Processing Record 7 of Set 6 | nanortalik
# Processing Record 8 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 6 | san quintin
# Processing Record 10 of Set 6 | sal rei
# Processing Record 11 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 12 of Set 6 | hokitika
# Processing Record 13 of Set 6 | cap malheureux
# Processing Record 14 of Set 6 | pangkalanbuun
# Processing Record 15 of Set 6 | porto novo
# Processing Record 16 of Set 6 | gupitan
# Processing Record 17 of Set 6 | iqaluit
# Processing Record 18 of Set 6 | silale
# Processing Record 19 of Set 6 | fare
# Processing Record 20 of Set 6 | pointe michel
# Processing Record 21 of Set 6 | tura
# Processing Record 22 of Set 6 | cherskiy
# Processing Record 23 of Set 6 | butaritari
# Processing Record 24 of Set 6 | baghdad
# Processing Record 25 of Set 6 | aguimes
# Processing Record 26 of Set 6 | mendi
# Processing Record 27 of Set 6 | shahreza
# Processing Record 28 of Set 6 | ust-nera
# Processing Record 29 of Set 6 | beloha
# Processing Record 30 of Set 6 | east london
# Processing Record 31 of Set 6 | lorengau
# Processing Record 32 of Set 6 | aden
# Processing Record 33 of Set 6 | vila franca do campo
# Processing Record 34 of Set 6 | upernavik
# Processing Record 35 of Set 6 | gayeri
# Processing Record 36 of Set 6 | cravo norte
# Processing Record 37 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 6 | bengkulu
# Processing Record 39 of Set 6 | broome
# Processing Record 40 of Set 6 | walajabad
# City not found. Skipping...
# Processing Record 41 of Set 6 | oxelosund
# Processing Record 42 of Set 6 | ensenada
# Processing Record 43 of Set 6 | ancud
# Processing Record 44 of Set 6 | belyy yar
# Processing Record 45 of Set 6 | dikson
# Processing Record 46 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 6 | ixtapa
# Processing Record 48 of Set 6 | vagur
# Processing Record 49 of Set 6 | calama
# Processing Record 50 of Set 6 | vardo
# Processing Record 1 of Set 7 | tuktoyaktuk
# Processing Record 2 of Set 7 | nuevo casas grandes
# Processing Record 3 of Set 7 | sitka
# Processing Record 4 of Set 7 | beringovskiy
# Processing Record 5 of Set 7 | gidole
# Processing Record 6 of Set 7 | port shepstone
# Processing Record 7 of Set 7 | sisian
# Processing Record 8 of Set 7 | tshela
# Processing Record 9 of Set 7 | mayumba
# Processing Record 10 of Set 7 | longuenesse
# Processing Record 11 of Set 7 | pevek
# Processing Record 12 of Set 7 | saldanha
# Processing Record 13 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 7 | margate
# Processing Record 15 of Set 7 | decatur
# Processing Record 16 of Set 7 | chandler
# Processing Record 17 of Set 7 | la ronge
# Processing Record 18 of Set 7 | luderitz
# Processing Record 19 of Set 7 | souillac
# Processing Record 20 of Set 7 | tarko-sale
# Processing Record 21 of Set 7 | lalomanu
# City not found. Skipping...
# Processing Record 22 of Set 7 | rize
# Processing Record 23 of Set 7 | ayorou
# Processing Record 24 of Set 7 | anadyr
# Processing Record 25 of Set 7 | cervo
# Processing Record 26 of Set 7 | taseyevo
# Processing Record 27 of Set 7 | aykhal
# Processing Record 28 of Set 7 | udachnyy
# Processing Record 29 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 30 of Set 7 | gorin
# Processing Record 31 of Set 7 | inuvik
# Processing Record 32 of Set 7 | sioux lookout
# Processing Record 33 of Set 7 | tome
# Processing Record 34 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 7 | tromso
# Processing Record 36 of Set 7 | beyneu
# Processing Record 37 of Set 7 | kampot
# Processing Record 38 of Set 7 | rocha
# Processing Record 39 of Set 7 | itarema
# Processing Record 40 of Set 7 | abu dhabi
# Processing Record 41 of Set 7 | bandarbeyla
# Processing Record 42 of Set 7 | hualmay
# Processing Record 43 of Set 7 | paracuru
# Processing Record 44 of Set 7 | ust-ilimsk
# Processing Record 45 of Set 7 | escanaba
# Processing Record 46 of Set 7 | chenghai
# Processing Record 47 of Set 7 | yar-sale
# Processing Record 48 of Set 7 | madarounfa
# Processing Record 49 of Set 7 | mazyr
# Processing Record 50 of Set 7 | huarmey
# Processing Record 1 of Set 8 | finnsnes
# Processing Record 2 of Set 8 | riohacha
# Processing Record 3 of Set 8 | broken hill
# Processing Record 4 of Set 8 | rio grande
# Processing Record 5 of Set 8 | geraldton
# Processing Record 6 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 8 | gari
# Processing Record 8 of Set 8 | tuxpan
# Processing Record 9 of Set 8 | kjollefjord
# Processing Record 10 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 8 | nabire
# Processing Record 12 of Set 8 | marsh harbour
# Processing Record 13 of Set 8 | north bend
# Processing Record 14 of Set 8 | harrogate
# Processing Record 15 of Set 8 | cartagena
# Processing Record 16 of Set 8 | necochea
# Processing Record 17 of Set 8 | tonstad
# Processing Record 18 of Set 8 | nalagarh
# Processing Record 19 of Set 8 | puerto rico
# Processing Record 20 of Set 8 | micheweni
# Processing Record 21 of Set 8 | kaitangata
# Processing Record 22 of Set 8 | jinchang
# Processing Record 23 of Set 8 | inirida
# Processing Record 24 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 25 of Set 8 | singaraja
# Processing Record 26 of Set 8 | colquiri
# Processing Record 27 of Set 8 | srednekolymsk
# Processing Record 28 of Set 8 | hede
# Processing Record 29 of Set 8 | durg
# Processing Record 30 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 8 | waipawa
# Processing Record 32 of Set 8 | westport
# Processing Record 33 of Set 8 | coquimbo
# Processing Record 34 of Set 8 | omboue
# Processing Record 35 of Set 8 | mahon
# Processing Record 36 of Set 8 | puerto madero
# Processing Record 37 of Set 8 | saint-pierre
# Processing Record 38 of Set 8 | tazovskiy
# Processing Record 39 of Set 8 | cravinhos
# Processing Record 40 of Set 8 | nome
# Processing Record 41 of Set 8 | itoman
# Processing Record 42 of Set 8 | maputo
# Processing Record 43 of Set 8 | harper
# Processing Record 44 of Set 8 | elko
# Processing Record 45 of Set 8 | bischofshofen
# Processing Record 46 of Set 8 | avera
# Processing Record 47 of Set 8 | grand gaube
# Processing Record 48 of Set 8 | havre
# Processing Record 49 of Set 8 | hurghada
# Processing Record 50 of Set 8 | tallahassee
# Processing Record 1 of Set 9 | antofagasta
# Processing Record 2 of Set 9 | khash
# Processing Record 3 of Set 9 | bow island
# Processing Record 4 of Set 9 | snezhnogorsk
# Processing Record 5 of Set 9 | ngunguru
# Processing Record 6 of Set 9 | caceres
# Processing Record 7 of Set 9 | russell
# Processing Record 8 of Set 9 | mindelo
# Processing Record 9 of Set 9 | shahr-e babak
# Processing Record 10 of Set 9 | glendive
# Processing Record 11 of Set 9 | mackay
# Processing Record 12 of Set 9 | leningradskiy
# Processing Record 13 of Set 9 | ovsyanka
# Processing Record 14 of Set 9 | gympie
# Processing Record 15 of Set 9 | filingue
# Processing Record 16 of Set 9 | quatre cocos
# Processing Record 17 of Set 9 | astoria
# Processing Record 18 of Set 9 | basco
# Processing Record 19 of Set 9 | ambon
# Processing Record 20 of Set 9 | mahonda
# Processing Record 21 of Set 9 | sao jose da coroa grande
# Processing Record 22 of Set 9 | naze
# Processing Record 23 of Set 9 | conde
# Processing Record 24 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 9 | port hedland
# Processing Record 26 of Set 9 | sorland
# Processing Record 27 of Set 9 | ugoofaaru
# Processing Record 28 of Set 9 | zhuhai
# Processing Record 29 of Set 9 | northam
# Processing Record 30 of Set 9 | lasa
# Processing Record 31 of Set 9 | det udom
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | ponta delgada
# Processing Record 34 of Set 9 | arlit
# Processing Record 35 of Set 9 | vallenar
# Processing Record 36 of Set 9 | jumla
# Processing Record 37 of Set 9 | salekhard
# Processing Record 38 of Set 9 | faya
# Processing Record 39 of Set 9 | ketchikan
# Processing Record 40 of Set 9 | oktyabrskiy
# Processing Record 41 of Set 9 | romilly-sur-seine
# Processing Record 42 of Set 9 | tocopilla
# Processing Record 43 of Set 9 | provideniya
# Processing Record 44 of Set 9 | kendari
# Processing Record 45 of Set 9 | severo-kurilsk
# Processing Record 46 of Set 9 | grindavik
# Processing Record 47 of Set 9 | honiara
# Processing Record 48 of Set 9 | comodoro rivadavia
# Processing Record 49 of Set 9 | dunedin
# Processing Record 50 of Set 9 | lazaro cardenas
# Processing Record 1 of Set 10 | myitkyina
# Processing Record 2 of Set 10 | kavaratti
# Processing Record 3 of Set 10 | canatlan
# Processing Record 4 of Set 10 | skaudvile
# Processing Record 5 of Set 10 | port macquarie
# Processing Record 6 of Set 10 | korla
# Processing Record 7 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 8 of Set 10 | bonfim
# Processing Record 9 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 11 of Set 10 | kuryk
# Processing Record 12 of Set 10 | nago
# Processing Record 13 of Set 10 | clyde river
# Processing Record 14 of Set 10 | nizwa
# Processing Record 15 of Set 10 | luau
# Processing Record 16 of Set 10 | ngama
# Processing Record 17 of Set 10 | hirna
# Processing Record 18 of Set 10 | changde
# Processing Record 19 of Set 10 | acapulco
# Processing Record 20 of Set 10 | tomatlan
# Processing Record 21 of Set 10 | san juan
# Processing Record 22 of Set 10 | humboldt
# Processing Record 23 of Set 10 | salalah
# Processing Record 24 of Set 10 | presidencia roque saenz pena
# Processing Record 25 of Set 10 | atambua
# Processing Record 26 of Set 10 | ossora
# Processing Record 27 of Set 10 | santa cruz del sur
# Processing Record 28 of Set 10 | zhengjiatun
# Processing Record 29 of Set 10 | bokoro
# Processing Record 30 of Set 10 | komsomolskiy
# Processing Record 31 of Set 10 | bethel
# Processing Record 32 of Set 10 | darhan
# Processing Record 33 of Set 10 | leh
# Processing Record 34 of Set 10 | calvinia
# Processing Record 35 of Set 10 | lompoc
# Processing Record 36 of Set 10 | clinton
# Processing Record 37 of Set 10 | jijiga
# Processing Record 38 of Set 10 | ouegoa
# Processing Record 39 of Set 10 | myaundzha
# Processing Record 40 of Set 10 | samarai
# Processing Record 41 of Set 10 | el dorado
# Processing Record 42 of Set 10 | praia da vitoria
# Processing Record 43 of Set 10 | vila velha
# Processing Record 44 of Set 10 | santiago
# Processing Record 45 of Set 10 | sidney
# Processing Record 46 of Set 10 | gat
# Processing Record 47 of Set 10 | matozinhos
# Processing Record 48 of Set 10 | yeniseysk
# Processing Record 49 of Set 10 | kaeo
# Processing Record 50 of Set 10 | esperance
# Processing Record 1 of Set 11 | los llanos de aridane
# Processing Record 2 of Set 11 | hay river
# Processing Record 3 of Set 11 | korgen
# Processing Record 4 of Set 11 | opuwo
# Processing Record 5 of Set 11 | sao felix do xingu
# Processing Record 6 of Set 11 | dangriga
# Processing Record 7 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 11 | xai-xai
# Processing Record 9 of Set 11 | verkhoyansk
# Processing Record 10 of Set 11 | rabo de peixe
# Processing Record 11 of Set 11 | iralaya
# Processing Record 12 of Set 11 | atikokan
# Processing Record 13 of Set 11 | wodonga
# Processing Record 14 of Set 11 | senanga
# Processing Record 15 of Set 11 | kozloduj
# City not found. Skipping...
# Processing Record 16 of Set 11 | kijang
# Processing Record 17 of Set 11 | bagli
# Processing Record 18 of Set 11 | zaria
# Processing Record 19 of Set 11 | port jervis
# Processing Record 20 of Set 11 | raga
# Processing Record 21 of Set 11 | morehead
# Processing Record 22 of Set 11 | lima
# Processing Record 23 of Set 11 | unity
# Processing Record 24 of Set 11 | san policarpo
# Processing Record 25 of Set 11 | chicama
# Processing Record 26 of Set 11 | seguin
# Processing Record 27 of Set 11 | sidi ali
# Processing Record 28 of Set 11 | emerald
# Processing Record 29 of Set 11 | san ignacio
# Processing Record 30 of Set 11 | redlands
# Processing Record 31 of Set 11 | constitucion
# Processing Record 32 of Set 11 | maine-soroa
# Processing Record 33 of Set 11 | yerbogachen
# Processing Record 34 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 35 of Set 11 | bowling green
# Processing Record 36 of Set 11 | sao joao da barra
# Processing Record 37 of Set 11 | shingu
# Processing Record 38 of Set 11 | katangli
# Processing Record 39 of Set 11 | pirganj
# Processing Record 40 of Set 11 | coahuayana
# Processing Record 41 of Set 11 | codrington
# Processing Record 42 of Set 11 | moyeuvre-grande
# Processing Record 43 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 11 | novikovo
# Processing Record 45 of Set 11 | mukhen
# Processing Record 46 of Set 11 | ormara
# Processing Record 47 of Set 11 | zhangjiakou
# Processing Record 48 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 11 | buala
# Processing Record 50 of Set 11 | saluzzo
# Processing Record 1 of Set 12 | la ciotat
# Processing Record 2 of Set 12 | lavrentiya
# Processing Record 3 of Set 12 | yuty
# Processing Record 4 of Set 12 | wahiawa
# Processing Record 5 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 12 | ginda
# Processing Record 8 of Set 12 | dafeng
# Processing Record 9 of Set 12 | paamiut
# Processing Record 10 of Set 12 | haines junction
# Processing Record 11 of Set 12 | balaipungut
# Processing Record 12 of Set 12 | bathsheba
# Processing Record 13 of Set 12 | pamanukan
# Processing Record 14 of Set 12 | sorong
# Processing Record 15 of Set 12 | hirara
# Processing Record 16 of Set 12 | ratnapura
# Processing Record 17 of Set 12 | ola
# Processing Record 18 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 19 of Set 12 | launceston
# Processing Record 20 of Set 12 | la palma
# Processing Record 21 of Set 12 | beirut
# Processing Record 22 of Set 12 | ledyard
# Processing Record 23 of Set 12 | mingshui
# Processing Record 24 of Set 12 | gushikawa
# Processing Record 25 of Set 12 | jalu
# Processing Record 26 of Set 12 | narsaq
# Processing Record 27 of Set 12 | fairbanks
# Processing Record 28 of Set 12 | cayenne
# Processing Record 29 of Set 12 | kurilsk
# Processing Record 30 of Set 12 | kananga
# Processing Record 31 of Set 12 | manokwari
# Processing Record 32 of Set 12 | santa cruz
# Processing Record 33 of Set 12 | sao gabriel da cachoeira
# Processing Record 34 of Set 12 | tuatapere
# Processing Record 35 of Set 12 | arona
# Processing Record 36 of Set 12 | gaoual
# Processing Record 37 of Set 12 | tabou
# Processing Record 38 of Set 12 | lom sak
# Processing Record 39 of Set 12 | ozieri
# Processing Record 40 of Set 12 | alyangula
# Processing Record 41 of Set 12 | truro
# Processing Record 42 of Set 12 | borovoy
# Processing Record 43 of Set 12 | richards bay
# Processing Record 44 of Set 12 | sola
# Processing Record 45 of Set 12 | ust-karsk
# Processing Record 46 of Set 12 | bilibino
# Processing Record 47 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 12 | moyale
# Processing Record 49 of Set 12 | isangel
# Processing Record 50 of Set 12 | nhulunbuy
# Processing Record 1 of Set 13 | mozarlandia
# Processing Record 2 of Set 13 | goderich
# Processing Record 3 of Set 13 | deputatskiy
# Processing Record 4 of Set 13 | hervey bay
# Processing Record 5 of Set 13 | kieta
# Processing Record 6 of Set 13 | numaligarh
# Processing Record 7 of Set 13 | planaltina
# Processing Record 8 of Set 13 | minab
# Processing Record 9 of Set 13 | marsa matruh
# Processing Record 10 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 13 | luanda
# Processing Record 12 of Set 13 | ibarra
# Processing Record 13 of Set 13 | brownwood
# Processing Record 14 of Set 13 | keflavik
# Processing Record 15 of Set 13 | nha trang
# Processing Record 16 of Set 13 | chute-aux-outardes
# Processing Record 17 of Set 13 | willmar
# Processing Record 18 of Set 13 | boffa
# Processing Record 19 of Set 13 | arosa
# Processing Record 20 of Set 13 | port-de-bouc
# Processing Record 21 of Set 13 | toucheng
# Processing Record 22 of Set 13 | mount isa
# Processing Record 23 of Set 13 | kazachinskoye
# Processing Record 24 of Set 13 | svetlaya
# Processing Record 25 of Set 13 | mmathubudukwane
# Processing Record 26 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 13 | qostanay
# Processing Record 28 of Set 13 | shitkino
# Processing Record 29 of Set 13 | cam ranh
# Processing Record 30 of Set 13 | mugan
# Processing Record 31 of Set 13 | the valley
# Processing Record 32 of Set 13 | lakatoro
# Processing Record 33 of Set 13 | iskateley
# Processing Record 34 of Set 13 | vidalia
# Processing Record 35 of Set 13 | nara
# Processing Record 36 of Set 13 | gunjur
# Processing Record 37 of Set 13 | kalabo
# Processing Record 38 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 39 of Set 13 | likasi
# Processing Record 40 of Set 13 | yenagoa
# Processing Record 41 of Set 13 | mazsalaca
# Processing Record 42 of Set 13 | teeli
# Processing Record 43 of Set 13 | labytnangi
# Processing Record 44 of Set 13 | dhidhdhoo
# Processing Record 45 of Set 13 | basoko
# Processing Record 46 of Set 13 | gushi
# Processing Record 47 of Set 13 | santo antonio do ica
# Processing Record 48 of Set 13 | daura
# Processing Record 49 of Set 13 | thilogne
# City not found. Skipping...
# Processing Record 50 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 1 of Set 14 | evensk
# Processing Record 2 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 3 of Set 14 | hun
# Processing Record 4 of Set 14 | zeya
# Processing Record 5 of Set 14 | upington
# Processing Record 6 of Set 14 | kimbe
# Processing Record 7 of Set 14 | buchanan
# Processing Record 8 of Set 14 | laurel
# Processing Record 9 of Set 14 | chlorakas
# Processing Record 10 of Set 14 | praia
# Processing Record 11 of Set 14 | bairiki
# Processing Record 12 of Set 14 | te anau
# Processing Record 13 of Set 14 | anshun
# Processing Record 14 of Set 14 | santa cruz de la palma
# Processing Record 15 of Set 14 | berlevag
# Processing Record 16 of Set 14 | bambanglipuro
# Processing Record 17 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 18 of Set 14 | kushiro
# Processing Record 19 of Set 14 | amboasary
# Processing Record 20 of Set 14 | debre birhan
# Processing Record 21 of Set 14 | boa vista
# Processing Record 22 of Set 14 | kununurra
# Processing Record 23 of Set 14 | alice springs
# Processing Record 24 of Set 14 | taburao
# City not found. Skipping...
# Processing Record 25 of Set 14 | verkhniy rohachyk
# Processing Record 26 of Set 14 | antalaha
# Processing Record 27 of Set 14 | saint-augustin
# Processing Record 28 of Set 14 | robertsport
# Processing Record 29 of Set 14 | campechuela
# Processing Record 30 of Set 14 | malanje
# Processing Record 31 of Set 14 | wenling
# Processing Record 32 of Set 14 | kulhudhuffushi
# Processing Record 33 of Set 14 | henties bay
# Processing Record 34 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 14 | uribia
# Processing Record 36 of Set 14 | suamico
# Processing Record 37 of Set 14 | dong xoai
# Processing Record 38 of Set 14 | erenhot
# Processing Record 39 of Set 14 | massakory
# Processing Record 40 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 41 of Set 14 | macomb
# Processing Record 42 of Set 14 | rochegda
# Processing Record 43 of Set 14 | riyadh
# Processing Record 44 of Set 14 | tlaxiaco
# City not found. Skipping...
# Processing Record 45 of Set 14 | lichuan
# Processing Record 46 of Set 14 | tamworth
# Processing Record 47 of Set 14 | saint-leu
# Processing Record 48 of Set 14 | sobolevo
# Processing Record 49 of Set 14 | mashhad
# Processing Record 50 of Set 14 | ulaanbaatar
# Processing Record 1 of Set 15 | pimentel
# Processing Record 2 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 4 of Set 15 | brae
# Processing Record 5 of Set 15 | chimbarongo
# Processing Record 6 of Set 15 | naugarzan
# City not found. Skipping...
# Processing Record 7 of Set 15 | teahupoo
# Processing Record 8 of Set 15 | gualaquiza
# Processing Record 9 of Set 15 | tual
# Processing Record 10 of Set 15 | yanji
# Processing Record 11 of Set 15 | salinopolis
# Processing Record 12 of Set 15 | shively
# Processing Record 13 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 15 | dongsheng
# Processing Record 15 of Set 15 | taksimo
# Processing Record 16 of Set 15 | manadhoo
# Processing Record 17 of Set 15 | srisailam
# Processing Record 18 of Set 15 | dese
# Processing Record 19 of Set 15 | point fortin
# Processing Record 20 of Set 15 | cabanas
# Processing Record 21 of Set 15 | aquiraz
# Processing Record 22 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 15 | cochrane
# Processing Record 24 of Set 15 | muravlenko
# Processing Record 25 of Set 15 | pokosnoye
# Processing Record 26 of Set 15 | kaohsiung
# Processing Record 27 of Set 15 | gorkovskiy
# Processing Record 28 of Set 15 | belgrade
# Processing Record 29 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 30 of Set 15 | putina
# Processing Record 31 of Set 15 | yabrud
# Processing Record 32 of Set 15 | urazovo
# Processing Record 33 of Set 15 | kapuskasing
# Processing Record 34 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 15 | coria
# Processing Record 36 of Set 15 | peleduy
# Processing Record 37 of Set 15 | bubaque
# Processing Record 38 of Set 15 | wladyslawowo
# Processing Record 39 of Set 15 | korcula
# Processing Record 40 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 15 | pangnirtung
# Processing Record 42 of Set 15 | mongu
# Processing Record 43 of Set 15 | tres arroyos
# Processing Record 44 of Set 15 | sabzevar
# Processing Record 45 of Set 15 | alta floresta
# Processing Record 46 of Set 15 | ponoka
# Processing Record 47 of Set 15 | hamilton
# Processing Record 48 of Set 15 | forbes
# Processing Record 49 of Set 15 | arman
# Processing Record 50 of Set 15 | gombe
# Processing Record 1 of Set 16 | soto la marina
# Processing Record 2 of Set 16 | sigli
# Processing Record 3 of Set 16 | abu samrah
# Processing Record 4 of Set 16 | gamboula
# Processing Record 5 of Set 16 | uarini
# Processing Record 6 of Set 16 | tommot
# Processing Record 7 of Set 16 | boyolangu
# Processing Record 8 of Set 16 | khanpur
# Processing Record 9 of Set 16 | port-gentil
# Processing Record 10 of Set 16 | moron
# Processing Record 11 of Set 16 | paulo ramos
# Processing Record 12 of Set 16 | sosva
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea -23.1203 -134.9692     79.00        71           0
# 1  Bambous Virieux -20.3428   57.7575     86.25        74          40
# 2    Mount Gambier -37.8333  140.7667     74.10        39         100
# 3           Nagato  34.3833  131.2000     46.35        87         100
# 4        Sistranda  63.7256    8.8340     41.90        73         100
# 5         Progreso  21.2833  -89.6667     72.10        90          34
# 6          Houston  29.7633  -95.3633     41.92        60           0
# 7           Hobart -42.8794  147.3294     77.02        48          75
# 8       Mahibadhoo   3.7833   72.9667     81.00        73         100
# 9          Xuanhua  40.6103  115.0447     24.26        74         100
#
#    Wind Speed Country                 Date
# 0       16.55      PF  2022-02-13 06:21:18
# 1       14.97      MU  2022-02-13 06:21:19
# 2        8.70      AU  2022-02-13 06:21:19
# 3        4.27      JP  2022-02-13 06:21:20
# 4       16.49      NO  2022-02-13 06:12:26
# 5       18.50      MX  2022-02-13 06:21:21
# 6       14.97      US  2022-02-13 06:19:17
# 7       16.11      AU  2022-02-13 06:18:28
# 8        4.61      MV  2022-02-13 06:21:22
# 9       11.07      CN  2022-02-13 06:21:22

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

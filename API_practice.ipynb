# %%
# Import the random module.
import random

# %%
random.randint(-90,90)
# Out:
# 29

# %%
random.random()
# Out:
# 0.6867231310403751

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
random.randrange(-90, 90, step=3)
# Out:
# -33

# %%
random.uniform(-90, 90)
# Out:
# -12.785437969361183

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -49.078177172565354

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([-2.18882267e+01,  9.47969249e+00, -3.63923326e+01, -8.61333042e+01,
#        -8.38119392e+01,  4.65623567e+01, -4.36518887e+01, -5.01295711e+01,
#         7.96941366e+01, -1.43419104e+01,  4.87028418e+01, -2.45895094e+01,
#         5.69914758e+01, -3.36164271e+01,  8.65652297e+01,  1.15268987e+01,
#        -4.95438983e+01, -2.03833158e+01, -5.04755653e+01, -7.63824357e+01,
#         2.14214137e+01,  4.45438067e+01,  5.48830785e+00, -6.03019456e+01,
#         3.76493844e+01, -1.11672406e+01, -4.40329055e+01,  2.56308422e+01,
#         4.87942054e+01,  4.46503484e+01,  6.49359614e+01,  3.52217244e+01,
#         4.00568933e+01, -3.45474501e+01, -6.91901863e+01,  1.99230534e+01,
#        -9.99286562e+00, -1.25626851e+01, -4.68721053e+01,  1.33664369e+01,
#         3.75477780e+01,  7.36698669e+01, -6.21790327e+01,  6.18576340e-02,
#        -4.38446125e+01,  6.34527990e+01, -4.88237376e+01,  3.15017988e+01,
#         8.52581085e+01, -2.93793207e+01])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 15.2 µs ± 640 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 2.03 ms ± 93.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# array([-59.85213093,   3.1820834 ,  62.02056488, ...,  -2.76745132,
#        -10.21896203,  30.31863009])

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/norgs/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/norgs/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/norgs/opt/anaconda3/envs/PythonData/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/norgs/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/norgs/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/norgs/opt/anaconda3/envs/PythonData/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# saint-philippe re
# mataura pf
# barentsburg sj
# bambous virieux mu
# ancud cl
# qaanaaq gl
# punta arenas cl
# ivankiv ua
# biloela au
# new norfolk au
# attawapiskat ca
# tessalit ml
# lasa cn
# mataura pf
# qaanaaq gl
# punta arenas cl
# rikitea pf
# shingu jp
# segou ml
# lebu cl
# attawapiskat ca
# hobart au
# atuona pf
# mataura pf
# busselton au
# labuhan id
# nicolas bravo mx
# georgetown sh
# cape town za
# saint george bm
# manggar id
# bluff nz
# paragominas br
# bethel us
# ponta do sol cv
# atuona pf
# usatove ua
# tiksi ru
# belushya guba ru
# dikson ru
# upernavik gl
# castro cl
# saint-philippe re
# port alfred za
# hilo us
# tuktoyaktuk ca
# taolanaro mg
# guerrero negro mx
# udachnyy ru
# victoria sc
# mubi ng
# lakki marwat pk
# tiksi ru
# otane nz
# feijo br
# nguruka tz
# concarneau fr
# svetlogorsk ru
# ushuaia ar
# hithadhoo mv
# flinders au
# rikitea pf
# barentsburg sj
# butaritari ki
# hilo us
# atuona pf
# jacmel ht
# hobart au
# busselton au
# rikitea pf
# hithadhoo mv
# lavrentiya ru
# avarua ck
# kahului us
# ketchikan us
# bilibino ru
# leningradskiy ru
# norman wells ca
# sitka us
# taolanaro mg
# nikolskoye ru
# provideniya ru
# punta arenas cl
# mataura pf
# mataura pf
# rikitea pf
# boke gn
# mykhaylivka ua
# esperance au
# raga sd
# cape town za
# zaysan kz
# tuktoyaktuk ca
# rikitea pf
# bud no
# muriti tz
# nyimba zm
# ahipara nz
# rikitea pf
# yellowknife ca
# uyuni bo
# guarapari br
# barrow us
# tocache pe
# yellowknife ca
# busselton au
# palencia es
# ushuaia ar
# vao nc
# butaritari ki
# tual id
# jamestown sh
# belaya gora ru
# mikhaylovka kz
# hermanus za
# mataura pf
# sao jose da coroa grande br
# port alfred za
# esperance au
# new norfolk au
# nizhneyansk ru
# labuhan id
# mawlaik mm
# hilo us
# iskateley ru
# carnarvon au
# changping cn
# harlingen nl
# leningradskiy ru
# bunia cd
# port blair in
# okhotsk ru
# warqla dz
# qaanaaq gl
# tasiilaq gl
# lac du bonnet ca
# bintulu my
# ushuaia ar
# castro cl
# illoqqortoormiut gl
# cape town za
# tumannyy ru
# attawapiskat ca
# raub my
# butaritari ki
# saint anthony ca
# pandan ph
# alofi nu
# nyrob ru
# taolanaro mg
# urumqi cn
# sorvag fo
# punta arenas cl
# pozo colorado py
# faanui pf
# rikitea pf
# chuy uy
# sitka us
# kaitangata nz
# cape town za
# grand river south east mu
# camalu mx
# kapaa us
# tikapur np
# cape town za
# mahebourg mu
# rikitea pf
# ushuaia ar
# nizhneyansk ru
# whitehorse ca
# bandrele yt
# tsihombe mg
# punta arenas cl
# rabat ma
# hilo us
# dikson ru
# nushki pk
# rikitea pf
# mataura pf
# west bay ky
# mataura pf
# tasiilaq gl
# khatanga ru
# ulladulla au
# puerto ayora ec
# punta arenas cl
# kapaa us
# chinhoyi zw
# avarua ck
# kapaa us
# rikitea pf
# troitsko-pechorsk ru
# bahir dar et
# chifeng cn
# shelburne ca
# busselton au
# mataura pf
# avarua ck
# hobart au
# ponta do sol cv
# umzimvubu za
# iqaluit ca
# waitara nz
# nanortalik gl
# asau tv
# fare pf
# ushuaia ar
# san patricio mx
# zaraza ve
# yaan cn
# kapaa us
# atar mr
# torbay ca
# inyonga tz
# amderma ru
# albany au
# mataura pf
# rikitea pf
# zemio cf
# luganville vu
# bluff nz
# cape town za
# mahebourg mu
# mount isa au
# saint george bm
# uvalde us
# punta arenas cl
# ushuaia ar
# mitchell us
# butaritari ki
# hobart au
# atuona pf
# nishihara jp
# jamestown sh
# ponta do sol cv
# lubango ao
# magnor no
# hobart au
# camacha pt
# cape town za
# hilo us
# mataura pf
# rodrigues alves br
# nikolskoye ru
# bambous virieux mu
# te anau nz
# port alfred za
# port alfred za
# kapaa us
# sayyan ye
# ushuaia ar
# kayerkan ru
# chapais ca
# hobart au
# tura ru
# bachaquero ve
# boden se
# sitka us
# taburi ph
# geraldton au
# taolanaro mg
# aiken us
# punta arenas cl
# zapolyarnyy ru
# kirya ru
# wuwei cn
# nikolskoye ru
# cherskiy ru
# tadine nc
# bluff nz
# shambu et
# eyl so
# kapaa us
# airai pw
# taolanaro mg
# srednekolymsk ru
# qaanaaq gl
# bhalki in
# ushuaia ar
# nikolskoye ru
# ilulissat gl
# bluff nz
# babu cn
# atar mr
# rikitea pf
# umzimvubu za
# airai pw
# talnakh ru
# prokhorovka ru
# hobart au
# cidreira br
# maine-soroa ne
# atikokan ca
# new norfolk au
# barrow us
# provideniya ru
# rikitea pf
# hermiston us
# namibe ao
# marcona pe
# aden ye
# edson ca
# vaini to
# taolanaro mg
# hobart au
# padang id
# jamestown sh
# constitucion cl
# provideniya ru
# constitucion mx
# ushuaia ar
# kapaa us
# thompson ca
# tarakan id
# port elizabeth za
# puerto ayora ec
# rikitea pf
# rikitea pf
# san joaquin bo
# boz uz
# vila franca do campo pt
# byron bay au
# new norfolk au
# visnes no
# lebu cl
# chumikan ru
# bargal so
# scottsboro us
# ushuaia ar
# qaanaaq gl
# sistranda no
# punta arenas cl
# albany au
# ust-tsilma ru
# tiksi ru
# rikitea pf
# tasiilaq gl
# hobart au
# cabo san lucas mx
# punganuru in
# nanortalik gl
# raudeberg no
# bluff nz
# mataura pf
# mount gambier au
# charters towers au
# east london za
# vaini to
# mayor pablo lagerenza py
# hilo us
# severo-kurilsk ru
# kapaa us
# chagda ru
# ushuaia ar
# ormara pk
# isangel vu
# flinders au
# along in
# fort nelson ca
# vardo no
# oktyabrskiy ru
# tuktoyaktuk ca
# minsk by
# kapaa us
# nizhneyansk ru
# aktash ru
# monrovia lr
# bambous virieux mu
# castro cl
# vestmannaeyjar is
# atuona pf
# walvis bay na
# muli mv
# albany au
# nove straseci cz
# hermanus za
# albany au
# mezen ru
# sistranda no
# ushuaia ar
# albany au
# ponta delgada pt
# belushya guba ru
# fortuna us
# ushuaia ar
# zhenlai cn
# magistralnyy ru
# kapaa us
# maragogi br
# saint-philippe re
# grand centre ca
# barentsburg sj
# bluff nz
# rikitea pf
# rikitea pf
# rikitea pf
# amderma ru
# bredasdorp za
# njombe tz
# rikitea pf
# kapaa us
# taolanaro mg
# busselton au
# souillac mu
# cape town za
# rock springs us
# icoana ro
# ushuaia ar
# busselton au
# port alfred za
# ushuaia ar
# lavrentiya ru
# tigil ru
# iquitos pe
# colares pt
# fortuna us
# ribeira grande pt
# atambua id
# ilulissat gl
# castro cl
# amderma ru
# tailai cn
# iqaluit ca
# barrow us
# paamiut gl
# tuatapere nz
# busselton au
# rawson ar
# mogadishu so
# jamestown sh
# kapaa us
# kasempa zm
# mys shmidta ru
# tipolo ph
# souillac mu
# komsomolskiy ru
# saint-philippe re
# belushya guba ru
# zapadnaya dvina ru
# bonfim br
# illoqqortoormiut gl
# sao filipe cv
# jamestown sh
# bluff nz
# alyangula au
# ahipara nz
# morgan city us
# port alfred za
# ostrovnoy ru
# mar del plata ar
# nizhneyansk ru
# ushuaia ar
# amazar ru
# saint george bm
# biggar ca
# saldanha za
# touros br
# ushuaia ar
# kununurra au
# kalmunai lk
# barrow us
# yellowknife ca
# codrington ag
# kapaa us
# punta arenas cl
# torbay ca
# goderich sl
# saleaula ws
# yellowknife ca
# bredasdorp za
# salalah om
# rikitea pf
# sao filipe cv
# mehamn no
# bredasdorp za
# jamestown sh
# tasiilaq gl
# auki sb
# chokurdakh ru
# uige ao
# moose factory ca
# arraial do cabo br
# mataura pf
# hithadhoo mv
# hobart au
# kahului us
# wairoa nz
# rikitea pf
# axim gh
# ushuaia ar
# ribeira grande pt
# ponta delgada pt
# chunoyar ru
# batagay ru
# kavieng pg
# thompson ca
# rikitea pf
# padang id
# dikson ru
# ribeira grande pt
# namatanai pg
# luderitz na
# oistins bb
# emporia us
# arraial do cabo br
# margate za
# punta arenas cl
# husavik is
# safwah sa
# hermanus za
# saint george bm
# hobart au
# ilulissat gl
# butaritari ki
# albany au
# marzuq ly
# iqaluit ca
# cape town za
# hermanus za
# tuatapere nz
# castro cl
# lompoc us
# nautla mx
# vaitape pf
# kapaa us
# jamestown sh
# hilo us
# ushuaia ar
# las palmas es
# east london za
# severo-kurilsk ru
# atuona pf
# airai pw
# tuktoyaktuk ca
# taoudenni ml
# pisco pe
# fortuna us
# chuy uy
# alofi nu
# eydhafushi mv
# busselton au
# jamestown sh
# hermanus za
# coihaique cl
# taolanaro mg
# rikitea pf
# sao filipe cv
# nikolskoye ru
# goundi td
# barcelos br
# mataura pf
# kodinsk ru
# kapaa us
# svetlaya ru
# faanui pf
# hermanus za
# benguela ao
# barrow us
# ushuaia ar
# high level ca
# butaritari ki
# new norfolk au
# upernavik gl
# nehe cn
# barrow us
# talnakh ru
# cooma au
# rikitea pf
# kahului us
# hermanus za
# butaritari ki
# mataura pf
# rikitea pf
# sarangani ph
# cape town za
# ushtobe kz
# hermanus za
# ordynskoye ru
# qaanaaq gl
# pierre us
# taolanaro mg
# taolanaro mg
# ribeira grande pt
# namibe ao
# bandarbeyla so
# taolanaro mg
# dunedin nz
# avarua ck
# pisco pe
# ushuaia ar
# busselton au
# victoria sc
# new norfolk au
# rikitea pf
# illoqqortoormiut gl
# zeya ru
# praia da vitoria pt
# klaksvik fo
# parana ar
# ushuaia ar
# rikitea pf
# barrow us
# busselton au
# lasa cn
# agadez ne
# port lincoln au
# tiksi ru
# aklavik ca
# washougal us
# mahebourg mu
# qaanaaq gl
# xining cn
# new norfolk au
# palabuhanratu id
# hermanus za
# upernavik gl
# fortuna us
# castro cl
# kharp ru
# norman wells ca
# panguna pg
# albany au
# kirakira sb
# jamestown sh
# thompson ca
# bossier city us
# jamestown sh
# turayf sa
# barrow us
# caravelas br
# punta arenas cl
# kiruna se
# saint-philippe re
# erice it
# vostok ru
# jamestown sh
# ostrovnoy ru
# lebu cl
# east london za
# port hedland au
# constitucion mx
# hithadhoo mv
# belmonte br
# bilibino ru
# rikitea pf
# dijkot pk
# mataura pf
# machaneng bw
# mataura pf
# illoqqortoormiut gl
# butaritari ki
# punta arenas cl
# pisco pe
# kaitangata nz
# taolanaro mg
# taolanaro mg
# klaksvik fo
# carnarvon au
# kattivakkam in
# avarua ck
# samarai pg
# turinsk ru
# kapaa us
# punta arenas cl
# krasnoselkup ru
# punta arenas cl
# longyearbyen sj
# vaini to
# puerto ayora ec
# rikitea pf
# narsaq gl
# hargeysa so
# belmonte br
# vihari pk
# mehran ir
# juba sd
# chokurdakh ru
# kavieng pg
# east london za
# harrisonburg us
# yulara au
# stornoway gb
# qaanaaq gl
# coacoyul mx
# illoqqortoormiut gl
# tuktoyaktuk ca
# georgetown sh
# albany au
# sitka us
# aklavik ca
# punta arenas cl
# sao raimundo nonato br
# tuktoyaktuk ca
# talnakh ru
# calderitas mx
# taolanaro mg
# osmaniye tr
# kapaa us
# zalantun cn
# mullaitivu lk
# belushya guba ru
# santa rosa del sur co
# albany au
# thompson ca
# kaitangata nz
# pompeu br
# tampakan ph
# sentyabrskiy ru
# paamiut gl
# pizhma ru
# punta arenas cl
# hobart au
# barbar sd
# salalah om
# pevek ru
# ushuaia ar
# busselton au
# lavrentiya ru
# albany au
# tarakan id
# tilichiki ru
# bandarbeyla so
# lvov ua
# punta arenas cl
# cherskiy ru
# ushuaia ar
# carndonagh ie
# busselton au
# jamestown sh
# olinda br
# kodiak us
# nanakuli us
# bredasdorp za
# busselton au
# tahe cn
# bambanglipuro id
# ewa beach us
# puerto ayora ec
# hilo us
# los llanos de aridane es
# ushuaia ar
# busselton au
# castro cl
# lumphat kh
# taolanaro mg
# nanortalik gl
# tuktoyaktuk ca
# haibowan cn
# ayorou ne
# bilma ne
# avarua ck
# burnie au
# yellowknife ca
# formosa ar
# upernavik gl
# busselton au
# amderma ru
# kruisfontein za
# sandwick gb
# markova ru
# ribeira grande pt
# chuy uy
# tuktoyaktuk ca
# hobart au
# nizhnevartovsk ru
# punta arenas cl
# albany au
# severo-kurilsk ru
# ambilobe mg
# tadine nc
# punta arenas cl
# norman wells ca
# yulara au
# khatanga ru
# hermanus za
# east london za
# vaini to
# mataura pf
# chokurdakh ru
# bambous virieux mu
# severo-kurilsk ru
# punta arenas cl
# vila franca do campo pt
# deputatskiy ru
# kuryk kz
# aksarka ru
# san pedro ar
# albany au
# pangnirtung ca
# lata sb
# rikitea pf
# isangel vu
# rikitea pf
# bredasdorp za
# barrow us
# fortuna us
# boden se
# souillac mu
# aswan eg
# resistencia ar
# rikitea pf
# karamay cn
# madingou cg
# khatanga ru
# ushuaia ar
# katsuura jp
# sao paulo de olivenca br
# mataura pf
# saleaula ws
# siocon ph
# albany au
# busselton au
# yanan cn
# hobart au
# krasnyy chikoy ru
# saleaula ws
# krasnoselkup ru
# shiyan cn
# sorvag fo
# mehamn no
# ribeira grande pt
# tasiilaq gl
# bawisan ph
# bandarbeyla so
# codrington ag
# dekar bw
# nikolskoye ru
# stornoway gb
# lompoc us
# xam nua la
# saquena pe
# balod in
# hithadhoo mv
# san cristobal ec
# belushya guba ru
# george town ky
# bambous virieux mu
# lompoc us
# henties bay na
# castro cl
# agirish ru
# sentyabrskiy ru
# sobradinho br
# willmar us
# mataura pf
# castro cl
# sitka us
# lompoc us
# bluff nz
# puerto baquerizo moreno ec
# dhidhdhoo mv
# pedasi pa
# spas-demensk ru
# weimar de
# norman wells ca
# yellowknife ca
# gobabis na
# guasdualito ve
# wakkanai jp
# solnechnyy ru
# ushuaia ar
# geraldton au
# castro cl
# tifton us
# saleaula ws
# udachnyy ru
# kapaa us
# victoria sc
# kachiry kz
# cody us
# port alfred za
# airai pw
# airai pw
# kapaa us
# acapulco mx
# saskylakh ru
# mataura pf
# aviles es
# ribeira grande pt
# sao joao da barra br
# georgetown sh
# ushuaia ar
# mataura pf
# price us
# port alfred za
# butaritari ki
# acapulco mx
# davila ph
# paharpur pk
# ribeira grande pt
# mataura pf
# port alfred za
# ushuaia ar
# sijunjung id
# bengkulu id
# katastarion gr
# hermanus za
# avarua ck
# ayagoz kz
# georgetown sh
# new norfolk au
# rajauri in
# mataura pf
# kununurra au
# ribeira grande pt
# sitka us
# mount gambier au
# brookhaven us
# rikitea pf
# samalaeulu ws
# hobart au
# vaitupu wf
# hithadhoo mv
# tura ru
# rocha uy
# severo-kurilsk ru
# albany au
# albany au
# katsuura jp
# copiapo cl
# hilo us
# khatanga ru
# cabo san lucas mx
# bengkulu id
# jiayuguan cn
# kimbe pg
# busselton au
# beian cn
# chokurdakh ru
# jamestown sh
# harper lr
# helena us
# cayenne gf
# verkhnyaya inta ru
# hermanus za
# berbera so
# antofagasta cl
# arimalam in
# east london za
# shimoda jp
# campos altos br
# carnarvon au
# cape town za
# phultala bd
# betioky mg
# belushya guba ru
# fare pf
# albany au
# tuktoyaktuk ca
# kruisfontein za
# bolobo cd
# lebu cl
# taolanaro mg
# saint-philippe re
# korla cn
# cape town za
# jitra my
# olafsvik is
# belushya guba ru
# bluff nz
# albany au
# roebourne au
# mataura pf
# yenagoa ng
# tungkang tw
# amderma ru
# ushuaia ar
# ust-kamchatsk ru
# nizhneyansk ru
# cabo san lucas mx
# san buenaventura mx
# cazaje ao
# satitoa ws
# bluff nz
# arraial do cabo br
# truro gb
# faanui pf
# amderma ru
# hambantota lk
# touros br
# mananara mg
# cape town za
# hasaki jp
# valparaiso cl
# kenai us
# tasiilaq gl
# ushuaia ar
# talnakh ru
# katsuura jp
# tiksi ru
# abu samrah qa
# aktash ru
# punta arenas cl
# luanda ao
# kalmunai lk
# coahuayana mx
# cape town za
# asfi ma
# puerto leguizamo co
# katherine au
# hermanus za
# port alfred za
# bluff nz
# ancud cl
# boende cd
# khatanga ru
# tezu in
# hilo us
# jamestown sh
# namibe ao
# esperance au
# tsihombe mg
# tsihombe mg
# punta arenas cl
# rikitea pf
# illoqqortoormiut gl
# severo-kurilsk ru
# tigil ru
# estevan ca
# airai pw
# kurilsk ru
# rawson ar
# rikitea pf
# thiers fr
# atuona pf
# esperance au
# chachapoyas pe
# yellowknife ca
# busselton au
# tiksi ru
# lagoa pt
# saint-denis re
# barentsburg sj
# leningradskiy ru
# hobart au
# jalu ly
# qaanaaq gl
# georgetown sh
# barabinsk ru
# vestmannaeyjar is
# ushuaia ar
# kapaa us
# tessalit ml
# broome au
# saint-philippe re
# hobart au
# palu id
# port elizabeth za
# albany au
# belushya guba ru
# mataura pf
# kitui ke
# ushuaia ar
# hithadhoo mv
# hithadhoo mv
# kapaa us
# vaitupu wf
# bandarbeyla so
# albany au
# qasigiannguit gl
# tonkino ru
# punta arenas cl
# karasjok no
# busselton au
# new norfolk au
# jamestown sh
# san patricio mx
# hasaki jp
# rikitea pf
# cherskiy ru
# chuy uy
# orlik ru
# alyangula au
# victoria sc
# hobart au
# bengkulu id
# arraial do cabo br
# hobart au
# new norfolk au
# punta arenas cl
# katsuura jp
# bredasdorp za
# kapaa us
# hamilton bm
# bengkulu id
# mataura pf
# dikson ru
# rikitea pf
# khartoum sd
# staunton us
# manavalakurichi in
# narsaq gl
# severo-kurilsk ru
# chokurdakh ru
# mataura pf
# bredasdorp za
# atambua id
# saint-philippe re
# carnarvon au
# hermanus za
# vaini to
# bacuit ph
# panapakkam in
# xuddur so
# jamestown sh
# saskylakh ru
# ribeira grande pt
# fortuna us
# ejura gh
# kapaa us
# kavieng pg
# panguna pg
# acapulco mx
# kununurra au
# east london za
# nizhneyansk ru
# male mv
# vaini to
# lavrentiya ru
# rikitea pf
# rio grande br
# upernavik gl
# hasaki jp
# college us
# lebu cl
# umzimvubu za
# norman wells ca
# sibolga id
# mataura pf
# taolanaro mg
# hamilton bm
# iqaluit ca
# marquette us
# richards bay za
# vaitupu wf
# ugoofaaru mv
# illoqqortoormiut gl
# salalah om
# marcona pe
# flin flon ca
# atuona pf
# tayoltita mx
# east london za
# port augusta au
# bredy ru
# busselton au
# coahuayana mx
# san matias bo
# san cristobal ec
# myanaung mm
# hobart au
# stalybridge gb
# attawapiskat ca
# khatanga ru
# san policarpo ph
# vaini to
# salekhard ru
# hermanus za
# vanavara ru
# nanortalik gl
# ribeira grande pt
# panguna pg
# muborak uz
# mataura pf
# phek in
# kaitangata nz
# souillac mu
# tuktoyaktuk ca
# saint-philippe re
# saldanha za
# talnakh ru
# bato ph
# pangnirtung ca
# castro cl
# laurel us
# punta arenas cl
# alice springs au
# wawa ca
# temple us
# port alfred za
# bluff nz
# saleaula ws
# mataura pf
# hermanus za
# albany au
# taolanaro mg
# novikovo ru
# mataura pf
# albany au
# illoqqortoormiut gl
# belushya guba ru
# mataura pf
# bouna ci
# nova olimpia br
# grand river south east mu
# elizabeth city us
# esil kz
# kurchum kz
# narsaq gl
# kodiak us
# saint-augustin ca
# geraldton ca
# taoudenni ml
# paamiut gl
# slave lake ca
# lamu ke
# georgetown sh
# georgetown sh
# ribeira grande pt
# bonavista ca
# itacoatiara br
# buala sb
# alekseyevsk ru
# saleaula ws
# busselton au
# lebu cl
# taolanaro mg
# severo-kurilsk ru
# albany au
# mataura pf
# norfolk us
# ushuaia ar
# grants us
# ushuaia ar
# bandarbeyla so
# jamestown sh
# belushya guba ru
# ponta do sol cv
# rikitea pf
# rikitea pf
# hithadhoo mv
# barra patuca hn
# rikitea pf
# juba sd
# hirara jp
# vestmanna fo
# puerto ayora ec
# bud no
# atuona pf
# saint simons us
# huarmey pe
# albany au
# atuona pf
# mataura pf
# tautira pf
# russkaya polyana ru
# arraial do cabo br
# suntar ru
# kodiak us
# tigil ru
# mataura pf
# tasiilaq gl
# churapcha ru
# nogliki ru
# mahebourg mu
# hilo us
# haines junction ca
# jamestown sh
# margate za
# mount gambier au
# barbar sd
# atuona pf
# khatanga ru
# bluff nz
# thompson ca
# east london za
# grantham gb
# punta arenas cl
# amderma ru
# bengkulu id
# virginia beach us
# punta arenas cl
# mataura pf
# mataura pf
# marcona pe
# punta arenas cl
# tasiilaq gl
# barentsburg sj
# ushuaia ar
# illoqqortoormiut gl
# chico us
# tawkar sd
# jamestown sh
# los llanos de aridane es
# ulaanbaatar mn
# nasice hr
# buchanan lr
# mar del plata ar
# point pedro lk
# puerto ayora ec
# albany au
# carbonia it
# butaritari ki
# albany au
# terrace ca
# korem et
# ushuaia ar
# ngunguru nz
# manoel urbano br
# clyde river ca
# zonguldak tr
# port alfred za
# illoqqortoormiut gl
# saleaula ws
# muravlenko ru
# dikson ru
# hermanus za
# nortelandia br
# yellowknife ca
# lakatoro vu
# pisco pe
# bredasdorp za
# punta arenas cl
# chapais ca
# chuy uy
# mahebourg mu
# chara ru
# ushuaia ar
# hobart au
# chuy uy
# taolanaro mg
# atuona pf
# georgetown sh
# morozovsk ru
# camacha pt
# codrington ag
# souillac mu
# norman wells ca
# saint-philippe re
# kodiak us
# port hardy ca
# atuona pf
# ushuaia ar
# kapaa us
# cape town za
# anaco ve
# rikitea pf
# upernavik gl
# east london za
# qaanaaq gl
# key west us
# torit sd
# esperance au
# saint-philippe re
# pangnirtung ca
# kapaa us
# rikitea pf
# kodiak us
# rikitea pf
# busselton au
# saint george bm
# hayvoron ua
# husavik is
# thompson ca
# ostrovnoy ru
# kapaa us
# taolanaro mg
# mahebourg mu
# avarua ck
# biak id
# dingle ie
# viligili mv
# antofagasta cl
# khatanga ru
# punta arenas cl
# yellowknife ca
# qaanaaq gl
# khatanga ru
# lata sb
# busselton au
# port alfred za
# meulaboh id
# new norfolk au
# qaanaaq gl
# waipawa nz
# bardiyah ly
# dingle ie
# qaanaaq gl
# ewa beach us
# tigil ru
# butaritari ki
# cidreira br
# carnarvon au
# henties bay na
# port alfred za
# avarua ck
# tiksi ru
# qaanaaq gl
# cidreira br
# ryotsu jp
# albany au
# mataura pf
# barrow us
# tuktoyaktuk ca
# busselton au
# isla mujeres mx
# calama cl
# hambantota lk
# new norfolk au
# mys shmidta ru
# rikitea pf
# punta arenas cl
# nikolskoye ru
# ponta do sol cv
# anadyr ru
# sorvag fo
# tazmalt dz
# shelburne ca
# mataura pf
# clyde river ca
# new norfolk au
# aykhal ru
# punta arenas cl
# carnarvon au
# yellowknife ca
# saskylakh ru
# guerrero negro mx
# taolanaro mg
# ushuaia ar
# east london za
# busselton au
# ilulissat gl
# banyo cm
# valdepenas es
# mar del plata ar
# torbay ca
# punta arenas cl
# puerto ayora ec
# taolanaro mg
# georgetown sh
# rudsar ir
# punta arenas cl
# mataura pf
# punta arenas cl
# busselton au
# severo-kurilsk ru
# castro cl
# mataura pf
# punta arenas cl
# palmer us
# vardo no
# vaini to
# skagastrond is
# rikitea pf
# albany au
# albany au
# takoradi gh
# mataura pf
# tessaoua ne
# cabo san lucas mx
# mozhaysk ru
# barahona do
# bambous virieux mu
# punta arenas cl
# ushuaia ar
# dikson ru
# ushuaia ar
# port hardy ca
# avarua ck
# coquimbo cl
# qaanaaq gl
# hermanus za
# ushuaia ar
# punta arenas cl
# ushuaia ar
# esperance au
# comodoro rivadavia ar
# roald no
# punta arenas cl
# oranjemund na
# bambous virieux mu
# northam au
# coquimbo cl
# qaanaaq gl
# ushuaia ar
# cabo san lucas mx
# naryan-mar ru
# higuey do
# illoqqortoormiut gl
# sitka us
# cidreira br
# fort walton beach us
# castro cl
# terrace bay ca
# rikitea pf
# avarua ck
# sayyan ye
# mackay au
# rayevskaya ru
# jasper us
# albany au
# biryusinsk ru
# bambous virieux mu
# constitucion mx
# marigot gp
# port elizabeth za
# garowe so
# vaini to
# albany au
# buraydah sa

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 610

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=55fbd21474beaf864ebecb1d5d7da73e

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=55fbd21474beaf864ebecb1d5d7da73e&q=Boston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
